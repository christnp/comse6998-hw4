# %% [markdown]
# # COMS-E6998-010: Homework 4 {-}
# __Name:__ Nicholas Christman (n2677)
# __Due:__  Nov. 22, 2002

# %%
from __future__ import print_function, division

import sys
import time
import os
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
from pprint import pprint

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import torchvision
from torchvision import datasets, models, transforms

# plt.ion()   # interactive mode

# set global seed
seed = 6998
torch.manual_seed(seed)

# %%
# use a GPU if there is one available
cuda_availability = torch.cuda.is_available()
if cuda_availability:
    device = torch.device('cuda:{}'.format(torch.cuda.current_device()))
else:
    device = 'cpu'
print('\n*************************')
print('GPU Available: {}'.format(cuda_availability))
print('Current Device: {}'.format(device))
print('*************************\n')
# display the GPU info
if cuda_availability:
    # !nvidia-smi
# Out:
# *************************
# GPU Available: True
# Current Device: cuda:0
# *************************
#
# Wed Nov 18 15:28:09 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.87.01    Driver Version: 418.87.01    CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P0    28W /  70W |     10MiB / 15079MiB |      5%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Problem 1 - Transfer learning: Shallow learning vs Finetuning, Pytorch (30) {-}
#
# Two major transfer learning scenarios are as follows:
# * Finetuning the base model: Instead of random initialization, we initialize the network with a pretrained network, like the one that is trained on Imagenet dataset. Rest of the training looks as usual however the learning rate schedule for transfer learning may be different.
# * Base model as fixed feature extractor: Here, we will freeze the weights for all of the network except that of the final fully connected layer. This last fully connected layer is replaced with a new one with random weights and only this layer is trained.
#
# The following references were used to answer this problem:
# [1] Pytorch blog. Transfer Learning for Computer Vision Tutorial by S. Chilamkurthy
# &emsp; Available at https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
# [2] Notes on Transfer Learning. CS231n Convolutional Neural Networks for Visual Recognition.
# &emsp; Available at https://cs231n.github.io/transfer-learning/
# [3] Visual Domain Decathlon (https://www.robots.ox.ac.uk/~vgg/decathlon/)

# %%
# used one time to extract dataset
# # to extract tar
# import tarfile
# tar = tarfile.open("data/ucf101.tar", 'r')
# tar.extractall()
# tar.close()

# %%
###### Functions for Problem 1 ######

# function taken from the Pytorch tutorial [2]
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated
    
def train_model(model, criterion, optimizer, scheduler, 
                num_epochs=25, gpu_check=False, 
                start_epoch=0, save_epochs=0, 
                save_dir='', history={}, verbose=0):
    since = time.time()
    
    print('Training model...')
    print('=' * 20)

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    
    # if we aren't loading a model, start a new history dict
    if not history:
        history = {'train': {
                            'epoch': [],
                            'time': [],
                            'lr': [],
                            'loss': [],
                            'acc': [],
                            'best_acc': 0.0
                        }, 
                   'val': {
                           'epoch': [],
                           'time': [],
                           'lr': [],
                           'loss': [],
                           'acc': [],
                           'best_acc': 0.0
                       }
                  }

    for epoch in range(start_epoch, num_epochs):
        
        print('Epoch {}/{} (lr = {:.3e})'.format(epoch+1, num_epochs,
                                             optimizer.param_groups[0]['lr']))
        
        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            phase_start = time.time()

            # use temp variable for brevity 
            epoch_hist = history[phase]

            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            num_iters = len(dataloaders[phase])
            iter_time = 0
            for iters, (inputs, labels) in enumerate(dataloaders[phase]):
                iter_start = time.time()
                # move data to "device" (i.e., GPU)
                inputs, labels = inputs.to(device), labels.to(device)
                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                iter_time += (time.time() - iter_start)
                if (iters % 10 == 0 or iters == num_iters) or verbose == 1:
                    loss_data = loss.item() 
                    print('\r{} [{}/{} ({:.0f}%)]   Time: {:.4f}   Loss: {:.4f}'.
                            format(phase_str[phase], 
                                   iters * len(inputs), 
                                   len(dataloaders[phase].dataset),
                                   100. * iters / len(dataloaders[phase]), 
                                   iter_time, loss_data), end='')
            # store some stats
            epoch_time = time.time() - phase_start

            if phase == 'train':
                scheduler.step()
            
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            print('\r{} [Done!]   Time: {:.4f}   Loss: {:.4f}   Acc: {:.4f}'.
                   format(phase_str[phase], epoch_time, 
                         epoch_loss, epoch_acc, end=''))

            # store the best accuracy and deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
#                 epoch_hist['best_acc'] = best_acc.data.cpu().numpy().item()
                best_model_wts = copy.deepcopy(model.state_dict())


            # store the history
            epoch_hist['epoch'].append(epoch) # added in case loading history
            epoch_hist['time'].append(epoch_time)
            epoch_hist['lr'].append(optimizer.param_groups[0]['lr'])
            epoch_hist['loss'].append(epoch_loss)
            epoch_hist['acc'].append(epoch_acc.data.cpu().numpy().item())
            epoch_hist['best_acc'] = np.max(epoch_hist['acc'])


        # for debug, check gpu performance
        if gpu_check:
            return model, history
        
        if (epoch > 0 and epoch != num_epochs-1) and \
            ((epoch+1) % save_epochs == 0 and save_dir):
            checkpoint=os.path.join(save_dir, 
                                    'E{}_checkpoint.th'.format(epoch+1))
            save_checkpoint({
                'epoch': epoch + 1,
                'state_dict': model.state_dict(),
                'best_acc': best_acc,
            }, filename=checkpoint)
            # dump the data for later
            json_file = os.path.join(save_dir,
                                     'E{}_history.json'.format(epoch+1))
            with open(json_file, 'w') as fp:
                json.dump(history, fp)
                
            print(' + Saved checkpoint \'{}\''.format(checkpoint))
        
        # console output        
        print('-' * 20)
    if save_dir:
        checkpoint= os.path.join(save_dir, 'final_model.th')
        # save the model
        save_checkpoint({
            'state_dict': model.state_dict(),
            'best_acc': best_acc,
        }, filename=checkpoint)
        # dump the data for later
        with open(os.path.join(save_dir,'final_history.json'), 'w') as fp:
            json.dump(history, fp)
        print(' + Saved checkpoint \'{}\''.format(checkpoint))
        
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, history

def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)
        

def load_checkpoint(model,model_dir,start_epoch):
    # if model exists, then try to load it
    path = os.path.join(model_dir,'E{}_checkpoint.th'.format(start_epoch))
    if os.path.isfile(path):
         # resume from checkpoint if Colab booted us during training
        print("=> Loading checkpoint '{}'".format(path))
        checkpoint = torch.load(path)
        start_epoch = checkpoint['epoch']
        best_acc = checkpoint['best_acc']
        model.load_state_dict(checkpoint['state_dict'])
        print("=> Loaded checkpoint (epoch {})" .format(checkpoint['epoch']))
    else:
        print("=> No checkpoint found at '{}'".format(path))
        sys.exit()
    # load history structure
    history_file = os.path.join(model_dir,'E{}_history.json'.format(start_epoch))
    if os.path.isfile(history_file):
        with open(history_file) as json_file:
            history = json.load(json_file) 
    else:
        print('History file \'{}\' does not exist.'.format(checkpoint))
   
    return model,history


def save_checkpoint(state, filename='checkpoint.pth.tar'):
    """
    Save the training model
    """
    torch.save(state, filename)
    
###### Global Vars for Problem 1 ######
phase_str = {'train': 'Training', 'val': 'Validating'}

# %%
# hyperparameters
batch_size = 64
num_epochs = 200
momentum = 0.9
lr_init = 0.001
lr_decay = 0.1
lr_epochs = [np.floor(0.3*num_epochs),
              np.floor(0.6*num_epochs),
              np.floor(0.9*num_epochs)]


train_phases = ['train', 'val']

# Data augmentation and normalization for training
# Just normalization for validation and test
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224), # ImageNet is 224x224x3, so we need to stay the same
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(224), # ImageNet is 224x224x3, so we need to stay the same
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# data_dir = 'data/dtd'
data_name = 'ucf101'
data_dir = os.path.join('data',data_name)

# the training & validation data
image_datasets = {}
dataloaders = {}
dataset_sizes = {}
for x in train_phases:
    image_datasets[x] = datasets.ImageFolder(os.path.join(data_dir, x), 
                                             data_transforms[x])

    dataloaders[x] = torch.utils.data.DataLoader(image_datasets[x], 
                                                 batch_size=batch_size,
                                                 shuffle=True, 
                                                 num_workers=4)
    
    dataset_sizes[x] = len(image_datasets[x])

# get some data info
class_names = image_datasets['train'].classes
num_classes = len(class_names)

print('Number of classes: {}'.format(num_classes))
for x in ['train', 'val']:
    print('Dataset \'{}\' size: {}'.format(x,dataset_sizes[x]))


# read in the annotations and get the actual class names
# ann_dir = 'data/dtd_ann'
ann_dir = os.path.join('data',data_name+'_ann')

# with open(os.path.join(ann_dir,'dtd_train.json')) as f:
with open(os.path.join(ann_dir,'ucf101_train.json')) as f:
    train_ann = json.load(f)
# extract the "class_names" (last 4 digits of category id) and actual names (class labels)
real_names = dict([ (str(cat['id'])[-4:], cat['name']) for cat in train_ann['categories'] ])
    
# Count the number of images per class
from collections import Counter
tmp = dict(Counter(image_datasets['train'].targets))
# for displaying, let's replace the class # with the actual class name
for k, v in real_names.items():
    tmp[v] = tmp[int(k)-1]
    del tmp[int(k)-1]
print('Number of images per class:')
min_vals = min(tmp.values())
# min_classes = [key for key in tmp if tmp[key] == min_vals] 
print('  > Minimum count of {}'.format(min_vals))
max_vals = max(tmp.values())
# max_classes = [key for key in tmp if tmp[key] == max_vals] 
print('  > Maximum count of {}'.format(max_vals))
avg_vals = np.mean(list(tmp.values()))
print('  > Mean count of {:0.3f}'.format(avg_vals))
# Out:
# Number of classes: 101
# Dataset 'train' size: 7585
# Dataset 'val' size: 1952
# Number of images per class:
#   > Minimum count of 57
#   > Maximum count of 96
#   > Mean count of 75.099

# %%
# Get a batch of training data
inputs, classes = next(iter(dataloaders['val']))
# select 4 unique classes to demo
uni, ind = np.unique(classes, return_index=True)
use = np.random.choice(ind, 4, replace=False)
# display samles
title = 'Samples of \'{}\' Dataset'.format(data_name)
fig = plt.figure(figsize=(10,4))
fig.suptitle(title, fontsize=16)
for i,u in enumerate(use):
    axn = fig.add_subplot(1, 4, i+1)
    axn.set_title(real_names[class_names[classes[u]]])
    axn.axis('off')
    axn.imshow(inputs[u].permute(1, 2, 0))     
plt.tight_layout(pad=1.0)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### 1(a)
# __Dataset Explanation:__
#
# For this problem I chose to use the [UCF101 - Action Recognition Dataset](https://www.crcv.ucf.edu/data/UCF101.php "ucf101 dataset"). According the the referenced website, the UCF101 dataset consists of "realistic action videos, collected from YouTube, having 101 action categories." As the descrption states, the UCF101 dataset has 101 classes representing different actions (e.g., longjump, headmassage, fencing, etc.). The data is split into training, validation, and test sets consiting of 7629, 1908, and 3783 images, respectively. As displayed above, the number of images per class varies: there is a minimum of 57 images per class, a maximum of 96 images per class, and a mean of 75.099 images per class. Also displayed above are 4 sample images from the dataset.
#
# *Note: The Visual Domain Decathlon dataset abstracted away the actual class names, so 4 extra lines of code (above) were implemened to grab the actual class names out of the annotations file.*

# %% [markdown]
# ### 1(b)
# Below we will load a pretrained Resnet50 model (using Pytorch)

# %%
prob_name = 'prob1b'
save_epochs = 10
history = {}

# prepare the pre-trained model
model_ft = models.resnet50(pretrained=True)
num_ftrs = model_ft.fc.in_features
# change the output layer to match number of new classes
model_ft.fc = nn.Linear(num_ftrs, num_classes)

# for checkpoints (save/load dir)
start_epoch = 0
save_dir = os.path.join('checkpoints',prob_name)
if not os.path.isdir(save_dir): os.mkdir(save_dir) # create save_dir
# model_ft, history = load_checkpoint(model_ft, save_dir, start_epoch) # uncomment to load model

# move model to the GPU
model_ft = model_ft.to(device)
cudnn.benchmark = True

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=lr_init, momentum=momentum)

# Decay learning rate per hyperparameters above
lr_scheduler_ft = torch.optim.lr_scheduler.MultiStepLR(optimizer_ft,
                                                      milestones=lr_epochs, 
                                                      gamma=lr_decay)#,
lr_scheduler_ft.last_epoch = start_epoch - 1

model_ft, history = train_model(model_ft, criterion, optimizer_ft, lr_scheduler_ft,
                                num_epochs=num_epochs, start_epoch=start_epoch, 
                                save_epochs=save_epochs, save_dir=save_dir, 
                                history=history, verbose=1)
# Out:
# Training model...
# ====================
# Epoch 1/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.9906   Loss: 4.5549   Acc: 0.0285
# Validating [Done!]   Time: 6.2745   Loss: 4.3802   Acc: 0.0599
# --------------------
# Epoch 2/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8311   Loss: 4.2227   Acc: 0.0784
# Validating [Done!]   Time: 6.3139   Loss: 3.9407   Acc: 0.1245
# --------------------
# Epoch 3/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7506   Loss: 3.8490   Acc: 0.1337
# Validating [Done!]   Time: 6.2988   Loss: 3.5161   Acc: 0.1803
# --------------------
# Epoch 4/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8217   Loss: 3.5144   Acc: 0.1801
# Validating [Done!]   Time: 6.3223   Loss: 3.1687   Acc: 0.2254
# --------------------
# Epoch 5/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7730   Loss: 3.2655   Acc: 0.2140
# Validating [Done!]   Time: 6.3305   Loss: 2.9435   Acc: 0.2761
# --------------------
# Epoch 6/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8558   Loss: 3.0604   Acc: 0.2538
# Validating [Done!]   Time: 6.3275   Loss: 2.7373   Acc: 0.3171
# --------------------
# Epoch 7/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8545   Loss: 2.8940   Acc: 0.2832
# Validating [Done!]   Time: 6.3617   Loss: 2.5713   Acc: 0.3581
# --------------------
# Epoch 8/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8472   Loss: 2.7664   Acc: 0.3111
# Validating [Done!]   Time: 6.3365   Loss: 2.4236   Acc: 0.3950
# --------------------
# Epoch 9/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8184   Loss: 2.5931   Acc: 0.3537
# Validating [Done!]   Time: 6.3193   Loss: 2.3187   Acc: 0.4088
# --------------------
# Epoch 10/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.6480   Loss: 2.4770   Acc: 0.3830
# Validating [Done!]   Time: 6.3182   Loss: 2.1546   Acc: 0.4390
#  + Saved checkpoint 'checkpoints/prob1b/E10_checkpoint.th'
# --------------------
# Epoch 11/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8462   Loss: 2.3732   Acc: 0.4004
# Validating [Done!]   Time: 6.3182   Loss: 2.0785   Acc: 0.4590
# --------------------
# Epoch 12/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8909   Loss: 2.2530   Acc: 0.4315
# Validating [Done!]   Time: 6.3350   Loss: 2.0005   Acc: 0.4780
# --------------------
# Epoch 13/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8277   Loss: 2.1847   Acc: 0.4484
# Validating [Done!]   Time: 6.3458   Loss: 1.9139   Acc: 0.4933
# --------------------
# Epoch 14/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8964   Loss: 2.0763   Acc: 0.4733
# Validating [Done!]   Time: 6.3719   Loss: 1.8144   Acc: 0.5236
# --------------------
# Epoch 15/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8130   Loss: 2.0002   Acc: 0.5022
# Validating [Done!]   Time: 6.3419   Loss: 1.7699   Acc: 0.5287
# --------------------
# Epoch 16/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7907   Loss: 1.9027   Acc: 0.5218
# Validating [Done!]   Time: 6.3437   Loss: 1.6886   Acc: 0.5497
# --------------------
# Epoch 17/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8265   Loss: 1.8322   Acc: 0.5392
# Validating [Done!]   Time: 6.3853   Loss: 1.6840   Acc: 0.5579
# --------------------
# Epoch 18/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7831   Loss: 1.7615   Acc: 0.5574
# Validating [Done!]   Time: 6.3267   Loss: 1.6072   Acc: 0.5733
# --------------------
# Epoch 19/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7771   Loss: 1.6842   Acc: 0.5710
# Validating [Done!]   Time: 6.3313   Loss: 1.5639   Acc: 0.5763
# --------------------
# Epoch 20/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7381   Loss: 1.6086   Acc: 0.5931
# Validating [Done!]   Time: 6.3249   Loss: 1.5560   Acc: 0.5809
#  + Saved checkpoint 'checkpoints/prob1b/E20_checkpoint.th'
# --------------------
# Epoch 21/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7773   Loss: 1.5831   Acc: 0.5974
# Validating [Done!]   Time: 6.3448   Loss: 1.4951   Acc: 0.6014
# --------------------
# Epoch 22/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7962   Loss: 1.4905   Acc: 0.6262
# Validating [Done!]   Time: 6.3406   Loss: 1.4592   Acc: 0.5953
# --------------------
# Epoch 23/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5752   Loss: 1.4396   Acc: 0.6393
# Validating [Done!]   Time: 6.3031   Loss: 1.4128   Acc: 0.6055
# --------------------
# Epoch 24/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.6167   Loss: 1.4248   Acc: 0.6421
# Validating [Done!]   Time: 6.3294   Loss: 1.4043   Acc: 0.6117
# --------------------
# Epoch 25/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7750   Loss: 1.3494   Acc: 0.6626
# Validating [Done!]   Time: 6.2894   Loss: 1.3811   Acc: 0.6173
# --------------------
# Epoch 26/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7328   Loss: 1.2772   Acc: 0.6795
# Validating [Done!]   Time: 6.3181   Loss: 1.3724   Acc: 0.6153
# --------------------
# Epoch 27/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.6332   Loss: 1.2699   Acc: 0.6837
# Validating [Done!]   Time: 6.3707   Loss: 1.3359   Acc: 0.6327
# --------------------
# Epoch 28/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.6544   Loss: 1.2066   Acc: 0.6987
# Validating [Done!]   Time: 6.3152   Loss: 1.3279   Acc: 0.6399
# --------------------
# Epoch 29/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7315   Loss: 1.1722   Acc: 0.7107
# Validating [Done!]   Time: 6.3501   Loss: 1.3304   Acc: 0.6429
# --------------------
# Epoch 30/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.6907   Loss: 1.1310   Acc: 0.7249
# Validating [Done!]   Time: 6.3017   Loss: 1.3095   Acc: 0.6434
#  + Saved checkpoint 'checkpoints/prob1b/E30_checkpoint.th'
# --------------------
# Epoch 31/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5797   Loss: 1.1096   Acc: 0.7202
# Validating [Done!]   Time: 6.3216   Loss: 1.2905   Acc: 0.6491
# --------------------
# Epoch 32/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.6691   Loss: 1.0779   Acc: 0.7299
# Validating [Done!]   Time: 6.3496   Loss: 1.3147   Acc: 0.6306
# --------------------
# Epoch 33/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7597   Loss: 1.0423   Acc: 0.7449
# Validating [Done!]   Time: 6.3415   Loss: 1.2721   Acc: 0.6522
# --------------------
# Epoch 34/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8535   Loss: 0.9998   Acc: 0.7557
# Validating [Done!]   Time: 6.3304   Loss: 1.2662   Acc: 0.6547
# --------------------
# Epoch 35/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8346   Loss: 0.9527   Acc: 0.7694
# Validating [Done!]   Time: 6.3426   Loss: 1.2719   Acc: 0.6475
# --------------------
# Epoch 36/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8336   Loss: 0.9444   Acc: 0.7681
# Validating [Done!]   Time: 6.3293   Loss: 1.2710   Acc: 0.6475
# --------------------
# Epoch 37/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7543   Loss: 0.9368   Acc: 0.7724
# Validating [Done!]   Time: 6.3161   Loss: 1.2517   Acc: 0.6532
# --------------------
# Epoch 38/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.6084   Loss: 0.8917   Acc: 0.7825
# Validating [Done!]   Time: 6.3056   Loss: 1.2543   Acc: 0.6578
# --------------------
# Epoch 39/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5446   Loss: 0.8833   Acc: 0.7822
# Validating [Done!]   Time: 6.3150   Loss: 1.2671   Acc: 0.6552
# --------------------
# Epoch 40/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5770   Loss: 0.8391   Acc: 0.7983
# Validating [Done!]   Time: 6.3181   Loss: 1.2275   Acc: 0.6609
#  + Saved checkpoint 'checkpoints/prob1b/E40_checkpoint.th'
# --------------------
# Epoch 41/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.6737   Loss: 0.8348   Acc: 0.7954
# Validating [Done!]   Time: 6.3330   Loss: 1.2497   Acc: 0.6496
# --------------------
# Epoch 42/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.6546   Loss: 0.7903   Acc: 0.8094
# Validating [Done!]   Time: 6.3135   Loss: 1.2293   Acc: 0.6655
# --------------------
# Epoch 43/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8044   Loss: 0.7626   Acc: 0.8152
# Validating [Done!]   Time: 6.3269   Loss: 1.1886   Acc: 0.6757
# --------------------
# Epoch 44/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7771   Loss: 0.7593   Acc: 0.8153
# Validating [Done!]   Time: 6.3106   Loss: 1.2160   Acc: 0.6644
# --------------------
# Epoch 45/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5399   Loss: 0.7570   Acc: 0.8191
# Validating [Done!]   Time: 6.2967   Loss: 1.2105   Acc: 0.6706
# --------------------
# Epoch 46/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.6610   Loss: 0.7383   Acc: 0.8208
# Validating [Done!]   Time: 6.3155   Loss: 1.2227   Acc: 0.6583
# --------------------
# Epoch 47/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7941   Loss: 0.7382   Acc: 0.8177
# Validating [Done!]   Time: 6.3105   Loss: 1.2146   Acc: 0.6629
# --------------------
# Epoch 48/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5341   Loss: 0.6843   Acc: 0.8341
# Validating [Done!]   Time: 6.3173   Loss: 1.2013   Acc: 0.6778
# --------------------
# Epoch 49/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8235   Loss: 0.7004   Acc: 0.8305
# Validating [Done!]   Time: 6.3081   Loss: 1.1699   Acc: 0.6824
# --------------------
# Epoch 50/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5756   Loss: 0.7060   Acc: 0.8260
# Validating [Done!]   Time: 6.3138   Loss: 1.2234   Acc: 0.6614
#  + Saved checkpoint 'checkpoints/prob1b/E50_checkpoint.th'
# --------------------
# Epoch 51/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5876   Loss: 0.7053   Acc: 0.8231
# Validating [Done!]   Time: 6.3177   Loss: 1.2198   Acc: 0.6706
# --------------------
# Epoch 52/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7304   Loss: 0.6725   Acc: 0.8370
# Validating [Done!]   Time: 6.3210   Loss: 1.1896   Acc: 0.6747
# --------------------
# Epoch 53/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.8420   Loss: 0.6639   Acc: 0.8372
# Validating [Done!]   Time: 6.3305   Loss: 1.1961   Acc: 0.6680
# --------------------
# Epoch 54/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7048   Loss: 0.6608   Acc: 0.8403
# Validating [Done!]   Time: 6.3107   Loss: 1.1723   Acc: 0.6762
# --------------------
# Epoch 55/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7798   Loss: 0.6164   Acc: 0.8506
# Validating [Done!]   Time: 6.3194   Loss: 1.1854   Acc: 0.6798
# --------------------
# Epoch 56/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5472   Loss: 0.6498   Acc: 0.8414
# Validating [Done!]   Time: 6.3131   Loss: 1.2188   Acc: 0.6639
# --------------------
# Epoch 57/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7769   Loss: 0.6148   Acc: 0.8506
# Validating [Done!]   Time: 6.3395   Loss: 1.1874   Acc: 0.6767
# --------------------
# Epoch 58/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7736   Loss: 0.6099   Acc: 0.8497
# Validating [Done!]   Time: 6.3338   Loss: 1.2096   Acc: 0.6783
# --------------------
# Epoch 59/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7977   Loss: 0.5918   Acc: 0.8543
# Validating [Done!]   Time: 6.3430   Loss: 1.2368   Acc: 0.6680
# --------------------
# Epoch 60/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7760   Loss: 0.5921   Acc: 0.8530
# Validating [Done!]   Time: 6.3891   Loss: 1.2044   Acc: 0.6783
#  + Saved checkpoint 'checkpoints/prob1b/E60_checkpoint.th'
# --------------------
# Epoch 61/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.7481   Loss: 0.5774   Acc: 0.8591
# Validating [Done!]   Time: 6.3302   Loss: 1.2123   Acc: 0.6737
# --------------------
# Epoch 62/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.8071   Loss: 0.5700   Acc: 0.8596
# Validating [Done!]   Time: 6.3591   Loss: 1.1651   Acc: 0.6844
# --------------------
# Epoch 63/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7494   Loss: 0.5474   Acc: 0.8678
# Validating [Done!]   Time: 6.3156   Loss: 1.1502   Acc: 0.6936
# --------------------
# Epoch 64/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5461   Loss: 0.5169   Acc: 0.8729
# Validating [Done!]   Time: 6.3115   Loss: 1.1468   Acc: 0.6921
# --------------------
# Epoch 65/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6610   Loss: 0.5006   Acc: 0.8770
# Validating [Done!]   Time: 6.3195   Loss: 1.1384   Acc: 0.6988
# --------------------
# Epoch 66/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7446   Loss: 0.5091   Acc: 0.8757
# Validating [Done!]   Time: 6.3135   Loss: 1.1449   Acc: 0.6906
# --------------------
# Epoch 67/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6713   Loss: 0.4880   Acc: 0.8807
# Validating [Done!]   Time: 6.3387   Loss: 1.1416   Acc: 0.6947
# --------------------
# Epoch 68/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5080   Loss: 0.5085   Acc: 0.8794
# Validating [Done!]   Time: 6.3085   Loss: 1.1440   Acc: 0.6936
# --------------------
# Epoch 69/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5300   Loss: 0.4936   Acc: 0.8836
# Validating [Done!]   Time: 6.3070   Loss: 1.1481   Acc: 0.6947
# --------------------
# Epoch 70/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7201   Loss: 0.4980   Acc: 0.8816
# Validating [Done!]   Time: 6.3306   Loss: 1.1437   Acc: 0.6952
#  + Saved checkpoint 'checkpoints/prob1b/E70_checkpoint.th'
# --------------------
# Epoch 71/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7153   Loss: 0.4911   Acc: 0.8825
# Validating [Done!]   Time: 6.3183   Loss: 1.1362   Acc: 0.6931
# --------------------
# Epoch 72/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7333   Loss: 0.4779   Acc: 0.8845
# Validating [Done!]   Time: 6.3596   Loss: 1.1381   Acc: 0.6911
# --------------------
# Epoch 73/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7666   Loss: 0.5107   Acc: 0.8744
# Validating [Done!]   Time: 6.3132   Loss: 1.1341   Acc: 0.6880
# --------------------
# Epoch 74/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7861   Loss: 0.4808   Acc: 0.8811
# Validating [Done!]   Time: 6.3265   Loss: 1.1341   Acc: 0.6972
# --------------------
# Epoch 75/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7797   Loss: 0.4868   Acc: 0.8833
# Validating [Done!]   Time: 6.3237   Loss: 1.1338   Acc: 0.6942
# --------------------
# Epoch 76/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6732   Loss: 0.4703   Acc: 0.8866
# Validating [Done!]   Time: 6.3276   Loss: 1.1369   Acc: 0.6972
# --------------------
# Epoch 77/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6586   Loss: 0.4794   Acc: 0.8838
# Validating [Done!]   Time: 6.3588   Loss: 1.1402   Acc: 0.6972
# --------------------
# Epoch 78/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7616   Loss: 0.4686   Acc: 0.8861
# Validating [Done!]   Time: 6.3080   Loss: 1.1371   Acc: 0.6983
# --------------------
# Epoch 79/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6507   Loss: 0.4823   Acc: 0.8782
# Validating [Done!]   Time: 6.3168   Loss: 1.1323   Acc: 0.6967
# --------------------
# Epoch 80/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5399   Loss: 0.4853   Acc: 0.8831
# Validating [Done!]   Time: 6.2939   Loss: 1.1362   Acc: 0.7003
#  + Saved checkpoint 'checkpoints/prob1b/E80_checkpoint.th'
# --------------------
# Epoch 81/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4973   Loss: 0.4748   Acc: 0.8866
# Validating [Done!]   Time: 6.3135   Loss: 1.1320   Acc: 0.6972
# --------------------
# Epoch 82/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7249   Loss: 0.4824   Acc: 0.8824
# Validating [Done!]   Time: 6.3176   Loss: 1.1338   Acc: 0.6947
# --------------------
# Epoch 83/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7133   Loss: 0.4786   Acc: 0.8849
# Validating [Done!]   Time: 6.3032   Loss: 1.1288   Acc: 0.6962
# --------------------
# Epoch 84/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6878   Loss: 0.4577   Acc: 0.8879
# Validating [Done!]   Time: 6.3087   Loss: 1.1260   Acc: 0.6972
# --------------------
# Epoch 85/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6289   Loss: 0.4891   Acc: 0.8795
# Validating [Done!]   Time: 6.3107   Loss: 1.1316   Acc: 0.6983
# --------------------
# Epoch 86/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6683   Loss: 0.4727   Acc: 0.8865
# Validating [Done!]   Time: 6.3034   Loss: 1.1346   Acc: 0.6983
# --------------------
# Epoch 87/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5774   Loss: 0.4604   Acc: 0.8883
# Validating [Done!]   Time: 6.3149   Loss: 1.1260   Acc: 0.7003
# --------------------
# Epoch 88/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7618   Loss: 0.4896   Acc: 0.8817
# Validating [Done!]   Time: 6.3550   Loss: 1.1291   Acc: 0.6936
# --------------------
# Epoch 89/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7149   Loss: 0.4605   Acc: 0.8871
# Validating [Done!]   Time: 6.3035   Loss: 1.1367   Acc: 0.6926
# --------------------
# Epoch 90/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5704   Loss: 0.4572   Acc: 0.8907
# Validating [Done!]   Time: 6.2893   Loss: 1.1300   Acc: 0.6906
#  + Saved checkpoint 'checkpoints/prob1b/E90_checkpoint.th'
# --------------------
# Epoch 91/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6046   Loss: 0.4543   Acc: 0.8914
# Validating [Done!]   Time: 6.3659   Loss: 1.1340   Acc: 0.6967
# --------------------
# Epoch 92/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6308   Loss: 0.4647   Acc: 0.8900
# Validating [Done!]   Time: 6.3098   Loss: 1.1246   Acc: 0.7008
# --------------------
# Epoch 93/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6310   Loss: 0.4635   Acc: 0.8893
# Validating [Done!]   Time: 6.3066   Loss: 1.1281   Acc: 0.6983
# --------------------
# Epoch 94/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5354   Loss: 0.4315   Acc: 0.8945
# Validating [Done!]   Time: 6.3096   Loss: 1.1380   Acc: 0.6993
# --------------------
# Epoch 95/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5982   Loss: 0.4770   Acc: 0.8828
# Validating [Done!]   Time: 6.3261   Loss: 1.1356   Acc: 0.6942
# --------------------
# Epoch 96/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6213   Loss: 0.4622   Acc: 0.8881
# Validating [Done!]   Time: 6.3499   Loss: 1.1290   Acc: 0.6967
# --------------------
# Epoch 97/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6986   Loss: 0.4725   Acc: 0.8861
# Validating [Done!]   Time: 6.3343   Loss: 1.1316   Acc: 0.6921
# --------------------
# Epoch 98/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7875   Loss: 0.4521   Acc: 0.8923
# Validating [Done!]   Time: 6.3227   Loss: 1.1339   Acc: 0.6931
# --------------------
# Epoch 99/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7570   Loss: 0.4625   Acc: 0.8890
# Validating [Done!]   Time: 6.2964   Loss: 1.1369   Acc: 0.6957
# --------------------
# Epoch 100/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.8073   Loss: 0.4491   Acc: 0.8915
# Validating [Done!]   Time: 6.3176   Loss: 1.1281   Acc: 0.7059
#  + Saved checkpoint 'checkpoints/prob1b/E100_checkpoint.th'
# --------------------
# Epoch 101/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7118   Loss: 0.4593   Acc: 0.8860
# Validating [Done!]   Time: 6.2850   Loss: 1.1328   Acc: 0.6947
# --------------------
# Epoch 102/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6504   Loss: 0.4660   Acc: 0.8882
# Validating [Done!]   Time: 6.3098   Loss: 1.1309   Acc: 0.6972
# --------------------
# Epoch 103/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7043   Loss: 0.4463   Acc: 0.8891
# Validating [Done!]   Time: 6.3214   Loss: 1.1333   Acc: 0.6942
# --------------------
# Epoch 104/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6709   Loss: 0.4475   Acc: 0.8922
# Validating [Done!]   Time: 6.3012   Loss: 1.1399   Acc: 0.6921
# --------------------
# Epoch 105/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6693   Loss: 0.4501   Acc: 0.8929
# Validating [Done!]   Time: 6.3222   Loss: 1.1327   Acc: 0.6983
# --------------------
# Epoch 106/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6298   Loss: 0.4526   Acc: 0.8907
# Validating [Done!]   Time: 6.3088   Loss: 1.1379   Acc: 0.6977
# --------------------
# Epoch 107/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6434   Loss: 0.4485   Acc: 0.8903
# Validating [Done!]   Time: 6.3002   Loss: 1.1351   Acc: 0.6988
# --------------------
# Epoch 108/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.7358   Loss: 0.4404   Acc: 0.8929
# Validating [Done!]   Time: 6.3416   Loss: 1.1256   Acc: 0.6988
# --------------------
# Epoch 109/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6460   Loss: 0.4603   Acc: 0.8912
# Validating [Done!]   Time: 6.3453   Loss: 1.1338   Acc: 0.6972
# --------------------
# Epoch 110/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5963   Loss: 0.4466   Acc: 0.8916
# Validating [Done!]   Time: 6.3017   Loss: 1.1415   Acc: 0.6977
#  + Saved checkpoint 'checkpoints/prob1b/E110_checkpoint.th'
# --------------------
# Epoch 111/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5224   Loss: 0.4601   Acc: 0.8864
# Validating [Done!]   Time: 6.2803   Loss: 1.1308   Acc: 0.7034
# --------------------
# Epoch 112/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4282   Loss: 0.4271   Acc: 0.8981
# Validating [Done!]   Time: 6.3089   Loss: 1.1389   Acc: 0.6977
# --------------------
# Epoch 113/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5144   Loss: 0.4433   Acc: 0.8924
# Validating [Done!]   Time: 6.3128   Loss: 1.1272   Acc: 0.6962
# --------------------
# Epoch 114/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5594   Loss: 0.4363   Acc: 0.8931
# Validating [Done!]   Time: 6.3119   Loss: 1.1396   Acc: 0.6942
# --------------------
# Epoch 115/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6646   Loss: 0.4666   Acc: 0.8877
# Validating [Done!]   Time: 6.3078   Loss: 1.1443   Acc: 0.6921
# --------------------
# Epoch 116/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6733   Loss: 0.4327   Acc: 0.8948
# Validating [Done!]   Time: 6.3029   Loss: 1.1366   Acc: 0.6931
# --------------------
# Epoch 117/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6807   Loss: 0.4419   Acc: 0.8936
# Validating [Done!]   Time: 6.3101   Loss: 1.1428   Acc: 0.6895
# --------------------
# Epoch 118/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6623   Loss: 0.4440   Acc: 0.8918
# Validating [Done!]   Time: 6.3006   Loss: 1.1354   Acc: 0.6931
# --------------------
# Epoch 119/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6632   Loss: 0.4531   Acc: 0.8898
# Validating [Done!]   Time: 6.3032   Loss: 1.1319   Acc: 0.6972
# --------------------
# Epoch 120/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6430   Loss: 0.4388   Acc: 0.8933
# Validating [Done!]   Time: 6.3022   Loss: 1.1307   Acc: 0.6967
#  + Saved checkpoint 'checkpoints/prob1b/E120_checkpoint.th'
# --------------------
# Epoch 121/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.6648   Loss: 0.4411   Acc: 0.8945
# Validating [Done!]   Time: 6.2901   Loss: 1.1311   Acc: 0.6890
# --------------------
# Epoch 122/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5515   Loss: 0.4447   Acc: 0.8932
# Validating [Done!]   Time: 6.3091   Loss: 1.1292   Acc: 0.6952
# --------------------
# Epoch 123/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5912   Loss: 0.4378   Acc: 0.8969
# Validating [Done!]   Time: 6.2942   Loss: 1.1305   Acc: 0.6983
# --------------------
# Epoch 124/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5478   Loss: 0.4113   Acc: 0.8993
# Validating [Done!]   Time: 6.2967   Loss: 1.1334   Acc: 0.6962
# --------------------
# Epoch 125/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5966   Loss: 0.4309   Acc: 0.8956
# Validating [Done!]   Time: 6.3025   Loss: 1.1332   Acc: 0.6972
# --------------------
# Epoch 126/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.7238   Loss: 0.4382   Acc: 0.8941
# Validating [Done!]   Time: 6.3261   Loss: 1.1268   Acc: 0.7018
# --------------------
# Epoch 127/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6745   Loss: 0.4211   Acc: 0.8958
# Validating [Done!]   Time: 6.3026   Loss: 1.1262   Acc: 0.6936
# --------------------
# Epoch 128/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.7123   Loss: 0.4544   Acc: 0.8878
# Validating [Done!]   Time: 6.3201   Loss: 1.1309   Acc: 0.6977
# --------------------
# Epoch 129/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6697   Loss: 0.4585   Acc: 0.8897
# Validating [Done!]   Time: 6.3160   Loss: 1.1289   Acc: 0.6957
# --------------------
# Epoch 130/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6665   Loss: 0.4301   Acc: 0.8943
# Validating [Done!]   Time: 6.3578   Loss: 1.1369   Acc: 0.6967
#  + Saved checkpoint 'checkpoints/prob1b/E130_checkpoint.th'
# --------------------
# Epoch 131/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6502   Loss: 0.4449   Acc: 0.8933
# Validating [Done!]   Time: 6.3049   Loss: 1.1316   Acc: 0.6947
# --------------------
# Epoch 132/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6838   Loss: 0.4225   Acc: 0.8980
# Validating [Done!]   Time: 6.2928   Loss: 1.1394   Acc: 0.6875
# --------------------
# Epoch 133/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6262   Loss: 0.4478   Acc: 0.8885
# Validating [Done!]   Time: 6.2969   Loss: 1.1293   Acc: 0.6916
# --------------------
# Epoch 134/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5278   Loss: 0.4195   Acc: 0.8995
# Validating [Done!]   Time: 6.2920   Loss: 1.1326   Acc: 0.6972
# --------------------
# Epoch 135/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6088   Loss: 0.4268   Acc: 0.8955
# Validating [Done!]   Time: 6.2839   Loss: 1.1261   Acc: 0.6942
# --------------------
# Epoch 136/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.4856   Loss: 0.4406   Acc: 0.8916
# Validating [Done!]   Time: 6.2996   Loss: 1.1273   Acc: 0.6890
# --------------------
# Epoch 137/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5476   Loss: 0.4462   Acc: 0.8902
# Validating [Done!]   Time: 6.3048   Loss: 1.1278   Acc: 0.6993
# --------------------
# Epoch 138/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5758   Loss: 0.4192   Acc: 0.8998
# Validating [Done!]   Time: 6.3103   Loss: 1.1259   Acc: 0.6952
# --------------------
# Epoch 139/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.7183   Loss: 0.4277   Acc: 0.8960
# Validating [Done!]   Time: 6.3411   Loss: 1.1306   Acc: 0.6957
# --------------------
# Epoch 140/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5199   Loss: 0.4330   Acc: 0.8947
# Validating [Done!]   Time: 6.2791   Loss: 1.1290   Acc: 0.6972
#  + Saved checkpoint 'checkpoints/prob1b/E140_checkpoint.th'
# --------------------
# Epoch 141/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.4744   Loss: 0.4287   Acc: 0.8966
# Validating [Done!]   Time: 6.2919   Loss: 1.1324   Acc: 0.6972
# --------------------
# Epoch 142/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6716   Loss: 0.4291   Acc: 0.8941
# Validating [Done!]   Time: 6.2777   Loss: 1.1357   Acc: 0.6957
# --------------------
# Epoch 143/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.7435   Loss: 0.4144   Acc: 0.9007
# Validating [Done!]   Time: 6.2944   Loss: 1.1278   Acc: 0.6967
# --------------------
# Epoch 144/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.7477   Loss: 0.4360   Acc: 0.8927
# Validating [Done!]   Time: 6.2865   Loss: 1.1288   Acc: 0.6947
# --------------------
# Epoch 145/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6998   Loss: 0.4227   Acc: 0.8998
# Validating [Done!]   Time: 6.3080   Loss: 1.1263   Acc: 0.6962
# --------------------
# Epoch 146/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5978   Loss: 0.4481   Acc: 0.8920
# Validating [Done!]   Time: 6.3125   Loss: 1.1241   Acc: 0.7018
# --------------------
# Epoch 147/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6129   Loss: 0.4420   Acc: 0.8916
# Validating [Done!]   Time: 6.3048   Loss: 1.1194   Acc: 0.7003
# --------------------
# Epoch 148/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5842   Loss: 0.4360   Acc: 0.8936
# Validating [Done!]   Time: 6.3363   Loss: 1.1278   Acc: 0.6952
# --------------------
# Epoch 149/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6769   Loss: 0.4114   Acc: 0.9006
# Validating [Done!]   Time: 6.3139   Loss: 1.1201   Acc: 0.7003
# --------------------
# Epoch 150/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6848   Loss: 0.4222   Acc: 0.8990
# Validating [Done!]   Time: 6.3203   Loss: 1.1279   Acc: 0.6936
#  + Saved checkpoint 'checkpoints/prob1b/E150_checkpoint.th'
# --------------------
# Epoch 151/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.7347   Loss: 0.4135   Acc: 0.8984
# Validating [Done!]   Time: 6.2992   Loss: 1.1273   Acc: 0.6936
# --------------------
# Epoch 152/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6258   Loss: 0.4438   Acc: 0.8937
# Validating [Done!]   Time: 6.3045   Loss: 1.1362   Acc: 0.6906
# --------------------
# Epoch 153/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6056   Loss: 0.4309   Acc: 0.8966
# Validating [Done!]   Time: 6.3027   Loss: 1.1319   Acc: 0.6977
# --------------------
# Epoch 154/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6835   Loss: 0.4314   Acc: 0.8920
# Validating [Done!]   Time: 6.2890   Loss: 1.1283   Acc: 0.6988
# --------------------
# Epoch 155/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6428   Loss: 0.4407   Acc: 0.8931
# Validating [Done!]   Time: 6.2996   Loss: 1.1281   Acc: 0.6972
# --------------------
# Epoch 156/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6315   Loss: 0.4311   Acc: 0.8928
# Validating [Done!]   Time: 6.3263   Loss: 1.1266   Acc: 0.6947
# --------------------
# Epoch 157/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6117   Loss: 0.4342   Acc: 0.8941
# Validating [Done!]   Time: 6.3489   Loss: 1.1304   Acc: 0.6926
# --------------------
# Epoch 158/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5654   Loss: 0.4314   Acc: 0.8985
# Validating [Done!]   Time: 6.2981   Loss: 1.1299   Acc: 0.6972
# --------------------
# Epoch 159/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5893   Loss: 0.4098   Acc: 0.9001
# Validating [Done!]   Time: 6.2789   Loss: 1.1240   Acc: 0.6972
# --------------------
# Epoch 160/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6620   Loss: 0.4158   Acc: 0.9030
# Validating [Done!]   Time: 6.2993   Loss: 1.1290   Acc: 0.6921
#  + Saved checkpoint 'checkpoints/prob1b/E160_checkpoint.th'
# --------------------
# Epoch 161/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5940   Loss: 0.4503   Acc: 0.8924
# Validating [Done!]   Time: 6.3034   Loss: 1.1332   Acc: 0.6993
# --------------------
# Epoch 162/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5931   Loss: 0.4227   Acc: 0.8977
# Validating [Done!]   Time: 6.3055   Loss: 1.1302   Acc: 0.6942
# --------------------
# Epoch 163/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5309   Loss: 0.4271   Acc: 0.8965
# Validating [Done!]   Time: 6.2777   Loss: 1.1368   Acc: 0.6952
# --------------------
# Epoch 164/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5400   Loss: 0.4349   Acc: 0.8941
# Validating [Done!]   Time: 6.3455   Loss: 1.1301   Acc: 0.6947
# --------------------
# Epoch 165/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6848   Loss: 0.4310   Acc: 0.8932
# Validating [Done!]   Time: 6.3229   Loss: 1.1257   Acc: 0.6962
# --------------------
# Epoch 166/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.7103   Loss: 0.4109   Acc: 0.8965
# Validating [Done!]   Time: 6.3037   Loss: 1.1271   Acc: 0.6957
# --------------------
# Epoch 167/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6238   Loss: 0.4170   Acc: 0.8969
# Validating [Done!]   Time: 6.3673   Loss: 1.1294   Acc: 0.6988
# --------------------
# Epoch 168/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6079   Loss: 0.4439   Acc: 0.8894
# Validating [Done!]   Time: 6.3111   Loss: 1.1325   Acc: 0.6901
# --------------------
# Epoch 169/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5372   Loss: 0.4236   Acc: 0.8962
# Validating [Done!]   Time: 6.3151   Loss: 1.1314   Acc: 0.6972
# --------------------
# Epoch 170/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5728   Loss: 0.4158   Acc: 0.8968
# Validating [Done!]   Time: 6.3104   Loss: 1.1260   Acc: 0.6967
#  + Saved checkpoint 'checkpoints/prob1b/E170_checkpoint.th'
# --------------------
# Epoch 171/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5287   Loss: 0.4351   Acc: 0.8964
# Validating [Done!]   Time: 6.2816   Loss: 1.1265   Acc: 0.6957
# --------------------
# Epoch 172/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5880   Loss: 0.4200   Acc: 0.9005
# Validating [Done!]   Time: 6.2928   Loss: 1.1371   Acc: 0.6962
# --------------------
# Epoch 173/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6705   Loss: 0.4344   Acc: 0.8936
# Validating [Done!]   Time: 6.2884   Loss: 1.1302   Acc: 0.6988
# --------------------
# Epoch 174/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6012   Loss: 0.4036   Acc: 0.9028
# Validating [Done!]   Time: 6.2902   Loss: 1.1253   Acc: 0.6972
# --------------------
# Epoch 175/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.7277   Loss: 0.4268   Acc: 0.9002
# Validating [Done!]   Time: 6.2885   Loss: 1.1362   Acc: 0.6895
# --------------------
# Epoch 176/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6591   Loss: 0.4130   Acc: 0.8984
# Validating [Done!]   Time: 6.2919   Loss: 1.1294   Acc: 0.6952
# --------------------
# Epoch 177/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.4723   Loss: 0.4093   Acc: 0.9032
# Validating [Done!]   Time: 6.2807   Loss: 1.1266   Acc: 0.6972
# --------------------
# Epoch 178/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5576   Loss: 0.4497   Acc: 0.8924
# Validating [Done!]   Time: 6.3089   Loss: 1.1364   Acc: 0.6926
# --------------------
# Epoch 179/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.6525   Loss: 0.4174   Acc: 0.8997
# Validating [Done!]   Time: 6.2796   Loss: 1.1384   Acc: 0.6906
# --------------------
# Epoch 180/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5986   Loss: 0.4328   Acc: 0.8927
# Validating [Done!]   Time: 6.3045   Loss: 1.1261   Acc: 0.6998
#  + Saved checkpoint 'checkpoints/prob1b/E180_checkpoint.th'
# --------------------
# Epoch 181/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5114   Loss: 0.4490   Acc: 0.8902
# Validating [Done!]   Time: 6.2457   Loss: 1.1332   Acc: 0.7003
# --------------------
# Epoch 182/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.2601   Loss: 0.4077   Acc: 0.8985
# Validating [Done!]   Time: 6.2904   Loss: 1.1320   Acc: 0.6926
# --------------------
# Epoch 183/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.5388   Loss: 0.4334   Acc: 0.8990
# Validating [Done!]   Time: 6.2702   Loss: 1.1325   Acc: 0.6962
# --------------------
# Epoch 184/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.6824   Loss: 0.4303   Acc: 0.8981
# Validating [Done!]   Time: 6.2932   Loss: 1.1269   Acc: 0.6972
# --------------------
# Epoch 185/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.6489   Loss: 0.4561   Acc: 0.8889
# Validating [Done!]   Time: 6.2746   Loss: 1.1263   Acc: 0.6921
# --------------------
# Epoch 186/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.5776   Loss: 0.4159   Acc: 0.9001
# Validating [Done!]   Time: 6.2909   Loss: 1.1291   Acc: 0.6957
# --------------------
# Epoch 187/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.6042   Loss: 0.4345   Acc: 0.8933
# Validating [Done!]   Time: 6.3087   Loss: 1.1280   Acc: 0.6993
# --------------------
# Epoch 188/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.6210   Loss: 0.4144   Acc: 0.9020
# Validating [Done!]   Time: 6.2889   Loss: 1.1241   Acc: 0.6942
# --------------------
# Epoch 189/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.7110   Loss: 0.4114   Acc: 0.8997
# Validating [Done!]   Time: 6.2811   Loss: 1.1231   Acc: 0.6967
# --------------------
# Epoch 190/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.6797   Loss: 0.4090   Acc: 0.9009
# Validating [Done!]   Time: 6.3080   Loss: 1.1292   Acc: 0.6998
#  + Saved checkpoint 'checkpoints/prob1b/E190_checkpoint.th'
# --------------------
# Epoch 191/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.5485   Loss: 0.4541   Acc: 0.8890
# Validating [Done!]   Time: 6.2895   Loss: 1.1284   Acc: 0.6962
# --------------------
# Epoch 192/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.4791   Loss: 0.4043   Acc: 0.9011
# Validating [Done!]   Time: 6.3145   Loss: 1.1247   Acc: 0.6977
# --------------------
# Epoch 193/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.5251   Loss: 0.4205   Acc: 0.8966
# Validating [Done!]   Time: 6.3461   Loss: 1.1347   Acc: 0.6931
# --------------------
# Epoch 194/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.6663   Loss: 0.4334   Acc: 0.8980
# Validating [Done!]   Time: 6.2968   Loss: 1.1253   Acc: 0.6942
# --------------------
# Epoch 195/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.6902   Loss: 0.4372   Acc: 0.8940
# Validating [Done!]   Time: 6.2852   Loss: 1.1281   Acc: 0.6962
# --------------------
# Epoch 196/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.5040   Loss: 0.4202   Acc: 0.8990
# Validating [Done!]   Time: 6.3130   Loss: 1.1295   Acc: 0.6957
# --------------------
# Epoch 197/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.5884   Loss: 0.4129   Acc: 0.9015
# Validating [Done!]   Time: 6.3182   Loss: 1.1292   Acc: 0.7024
# --------------------
# Epoch 198/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.6637   Loss: 0.4414   Acc: 0.8927
# Validating [Done!]   Time: 6.3362   Loss: 1.1280   Acc: 0.6967
# --------------------
# Epoch 199/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.6346   Loss: 0.4370   Acc: 0.8914
# Validating [Done!]   Time: 6.3405   Loss: 1.1356   Acc: 0.6936
# --------------------
# Epoch 200/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.6068   Loss: 0.4183   Acc: 0.8976
# Validating [Done!]   Time: 6.3098   Loss: 1.1273   Acc: 0.6993
# --------------------
#  + Saved checkpoint 'checkpoints/prob1b/final_model.th'
# Training complete in 276m 39s
# Best val Acc: 0.705943

# %% [markdown]
# _Note: the following snippet was copied from the actual console output that included all 200 epochs. Here the output is shortened for brevity, but still illustrates the learning rate decay as well as shows the first and last epoch._
# ```
# Training model...
# ====================
# Epoch 1/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.9906   Loss: 4.5549   Acc: 0.0285
# Validating [Done!]   Time: 6.2745   Loss: 4.3802   Acc: 0.0599
# --------------------
# ...
# --------------------
# Epoch 62/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.8071   Loss: 0.5700   Acc: 0.8596
# Validating [Done!]   Time: 6.3591   Loss: 1.1651   Acc: 0.6844
# --------------------
# ...
# --------------------
# Epoch 122/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5515   Loss: 0.4447   Acc: 0.8932
# Validating [Done!]   Time: 6.3091   Loss: 1.1292   Acc: 0.6952
# --------------------
# ...
# --------------------
# Epoch 182/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.2601   Loss: 0.4077   Acc: 0.8985
# Validating [Done!]   Time: 6.2904   Loss: 1.1320   Acc: 0.6926
# --------------------
# ...
# --------------------
# Epoch 200/200 (lr = 1.000e-06)
# Training [Done!]   Time: 76.6068   Loss: 0.4183   Acc: 0.8976
# Validating [Done!]   Time: 6.3098   Loss: 1.1273   Acc: 0.6993
# --------------------
#  + Saved checkpoint 'checkpoints/prob1b/final_model.th'
# Training complete in 276m 39s
# Best val Acc: 0.705943
# ```

# %% [markdown]
# ### 1(c)
# _Per Piazza @283, we will have different initial LRs but will still decay at the same rate._

# %%
prob_name = 'prob1c_1'
save_epochs = 10
history = {}

##### PART 1: LR = 0.01
# for this part, we set initial training rate to 0.01
# but will use the same decay schedule
lr_init = 0.01

# prepare the pre-trained model
model_ft = models.resnet50(pretrained=True)
num_ftrs = model_ft.fc.in_features
# change the output layer to match number of new classes
model_ft.fc = nn.Linear(num_ftrs, num_classes)

# for checkpoints (save/load dir)
start_epoch = 0
save_dir = os.path.join('checkpoints',prob_name)
if not os.path.isdir(save_dir): os.mkdir(save_dir) # create save_dir
# model_ft, history = load_checkpoint(model_ft, save_dir, start_epoch) # uncomment to load model

# move model to the GPU
model_ft = model_ft.to(device)
cudnn.benchmark = True

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=lr_init, momentum=momentum)

# Decay learning rate per hyperparameters above
lr_scheduler_ft = torch.optim.lr_scheduler.MultiStepLR(optimizer_ft,
                                                      milestones=lr_epochs, 
                                                      gamma=lr_decay)#,
lr_scheduler_ft.last_epoch = start_epoch - 1

model_ft, history = train_model(model_ft, criterion, optimizer_ft, lr_scheduler_ft,
                                num_epochs=num_epochs, start_epoch=start_epoch, 
                                save_epochs=save_epochs, save_dir=save_dir, 
                                history=history, verbose=1)
# Out:
# Training model...
# ====================
# Epoch 1/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.6766   Loss: 3.9958   Acc: 0.0961
# Validating [Done!]   Time: 6.2765   Loss: 3.3706   Acc: 0.1870
# --------------------
# Epoch 2/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.1910   Loss: 3.0099   Acc: 0.2402
# Validating [Done!]   Time: 6.2578   Loss: 2.6876   Acc: 0.3274
# --------------------
# Epoch 3/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5241   Loss: 2.5836   Acc: 0.3403
# Validating [Done!]   Time: 6.2868   Loss: 2.4375   Acc: 0.3919
# --------------------
# Epoch 4/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5296   Loss: 2.3115   Acc: 0.4038
# Validating [Done!]   Time: 6.3285   Loss: 2.0849   Acc: 0.4611
# --------------------
# Epoch 5/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5958   Loss: 2.1056   Acc: 0.4463
# Validating [Done!]   Time: 6.3213   Loss: 1.9008   Acc: 0.5020
# --------------------
# Epoch 6/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5491   Loss: 1.8732   Acc: 0.4999
# Validating [Done!]   Time: 6.2670   Loss: 1.9150   Acc: 0.4964
# --------------------
# Epoch 7/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4845   Loss: 1.7387   Acc: 0.5383
# Validating [Done!]   Time: 6.2775   Loss: 1.7305   Acc: 0.5528
# --------------------
# Epoch 8/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.2834   Loss: 1.6209   Acc: 0.5664
# Validating [Done!]   Time: 6.2598   Loss: 1.7404   Acc: 0.5369
# --------------------
# Epoch 9/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.2410   Loss: 1.5578   Acc: 0.5862
# Validating [Done!]   Time: 6.2854   Loss: 1.8575   Acc: 0.5389
# --------------------
# Epoch 10/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5075   Loss: 1.4482   Acc: 0.6178
# Validating [Done!]   Time: 6.2683   Loss: 1.6766   Acc: 0.5651
#  + Saved checkpoint 'checkpoints/prob1c_1/E10_checkpoint.th'
# --------------------
# Epoch 11/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5219   Loss: 1.3203   Acc: 0.6444
# Validating [Done!]   Time: 6.2775   Loss: 1.5971   Acc: 0.5953
# --------------------
# Epoch 12/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.3034   Loss: 1.2875   Acc: 0.6601
# Validating [Done!]   Time: 6.3011   Loss: 1.5905   Acc: 0.6142
# --------------------
# Epoch 13/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.3295   Loss: 1.2318   Acc: 0.6661
# Validating [Done!]   Time: 6.2825   Loss: 1.6204   Acc: 0.5902
# --------------------
# Epoch 14/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.3838   Loss: 1.1534   Acc: 0.6922
# Validating [Done!]   Time: 6.3188   Loss: 1.6488   Acc: 0.5881
# --------------------
# Epoch 15/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5052   Loss: 1.0974   Acc: 0.7077
# Validating [Done!]   Time: 6.3212   Loss: 1.5448   Acc: 0.6122
# --------------------
# Epoch 16/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5227   Loss: 1.0449   Acc: 0.7229
# Validating [Done!]   Time: 6.3200   Loss: 1.4146   Acc: 0.6470
# --------------------
# Epoch 17/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.3782   Loss: 1.0108   Acc: 0.7288
# Validating [Done!]   Time: 6.2737   Loss: 1.4908   Acc: 0.6317
# --------------------
# Epoch 18/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.3323   Loss: 0.9572   Acc: 0.7405
# Validating [Done!]   Time: 6.2852   Loss: 1.4550   Acc: 0.6460
# --------------------
# Epoch 19/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.3737   Loss: 0.9403   Acc: 0.7506
# Validating [Done!]   Time: 6.3182   Loss: 1.4670   Acc: 0.6491
# --------------------
# Epoch 20/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4607   Loss: 0.9636   Acc: 0.7403
# Validating [Done!]   Time: 6.3050   Loss: 1.4477   Acc: 0.6358
#  + Saved checkpoint 'checkpoints/prob1c_1/E20_checkpoint.th'
# --------------------
# Epoch 21/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4448   Loss: 0.8782   Acc: 0.7645
# Validating [Done!]   Time: 6.2883   Loss: 1.4677   Acc: 0.6634
# --------------------
# Epoch 22/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.0997   Loss: 0.8915   Acc: 0.7666
# Validating [Done!]   Time: 6.2758   Loss: 1.4017   Acc: 0.6624
# --------------------
# Epoch 23/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4757   Loss: 0.8536   Acc: 0.7726
# Validating [Done!]   Time: 6.2768   Loss: 1.4237   Acc: 0.6624
# --------------------
# Epoch 24/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.2841   Loss: 0.8479   Acc: 0.7698
# Validating [Done!]   Time: 6.2851   Loss: 1.2988   Acc: 0.6808
# --------------------
# Epoch 25/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.2451   Loss: 0.8087   Acc: 0.7830
# Validating [Done!]   Time: 6.2899   Loss: 1.3503   Acc: 0.6737
# --------------------
# Epoch 26/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.3298   Loss: 0.7882   Acc: 0.7892
# Validating [Done!]   Time: 6.2716   Loss: 1.3958   Acc: 0.6767
# --------------------
# Epoch 27/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5338   Loss: 0.7450   Acc: 0.8021
# Validating [Done!]   Time: 6.2950   Loss: 1.3820   Acc: 0.6619
# --------------------
# Epoch 28/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5831   Loss: 0.7263   Acc: 0.8063
# Validating [Done!]   Time: 6.2873   Loss: 1.2922   Acc: 0.6906
# --------------------
# Epoch 29/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4662   Loss: 0.7600   Acc: 0.7929
# Validating [Done!]   Time: 6.2848   Loss: 1.3891   Acc: 0.6773
# --------------------
# Epoch 30/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4781   Loss: 0.7706   Acc: 0.7945
# Validating [Done!]   Time: 6.2760   Loss: 1.4915   Acc: 0.6578
#  + Saved checkpoint 'checkpoints/prob1c_1/E30_checkpoint.th'
# --------------------
# Epoch 31/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4044   Loss: 0.7000   Acc: 0.8134
# Validating [Done!]   Time: 6.2865   Loss: 1.4011   Acc: 0.6721
# --------------------
# Epoch 32/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5636   Loss: 0.7079   Acc: 0.8058
# Validating [Done!]   Time: 6.2823   Loss: 1.5621   Acc: 0.6440
# --------------------
# Epoch 33/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5369   Loss: 0.6470   Acc: 0.8330
# Validating [Done!]   Time: 6.2977   Loss: 1.4025   Acc: 0.6742
# --------------------
# Epoch 34/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5481   Loss: 0.6988   Acc: 0.8136
# Validating [Done!]   Time: 6.2862   Loss: 1.3937   Acc: 0.6757
# --------------------
# Epoch 35/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4700   Loss: 0.6649   Acc: 0.8228
# Validating [Done!]   Time: 6.3157   Loss: 1.2724   Acc: 0.6936
# --------------------
# Epoch 36/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4691   Loss: 0.6286   Acc: 0.8336
# Validating [Done!]   Time: 6.2962   Loss: 1.3879   Acc: 0.6952
# --------------------
# Epoch 37/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4622   Loss: 0.6624   Acc: 0.8290
# Validating [Done!]   Time: 6.2850   Loss: 1.3451   Acc: 0.7018
# --------------------
# Epoch 38/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4285   Loss: 0.6348   Acc: 0.8283
# Validating [Done!]   Time: 6.2999   Loss: 1.3120   Acc: 0.6926
# --------------------
# Epoch 39/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4904   Loss: 0.6200   Acc: 0.8322
# Validating [Done!]   Time: 6.2879   Loss: 1.3832   Acc: 0.6803
# --------------------
# Epoch 40/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4801   Loss: 0.6391   Acc: 0.8318
# Validating [Done!]   Time: 6.2840   Loss: 1.2753   Acc: 0.7136
#  + Saved checkpoint 'checkpoints/prob1c_1/E40_checkpoint.th'
# --------------------
# Epoch 41/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.1718   Loss: 0.6524   Acc: 0.8250
# Validating [Done!]   Time: 6.2651   Loss: 1.3045   Acc: 0.7075
# --------------------
# Epoch 42/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.2587   Loss: 0.6141   Acc: 0.8384
# Validating [Done!]   Time: 6.2879   Loss: 1.3220   Acc: 0.7003
# --------------------
# Epoch 43/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4605   Loss: 0.6182   Acc: 0.8328
# Validating [Done!]   Time: 6.2822   Loss: 1.3318   Acc: 0.6860
# --------------------
# Epoch 44/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5901   Loss: 0.5605   Acc: 0.8486
# Validating [Done!]   Time: 6.2771   Loss: 1.3613   Acc: 0.6834
# --------------------
# Epoch 45/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4118   Loss: 0.5754   Acc: 0.8468
# Validating [Done!]   Time: 6.2709   Loss: 1.2717   Acc: 0.6972
# --------------------
# Epoch 46/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.3754   Loss: 0.5769   Acc: 0.8476
# Validating [Done!]   Time: 6.2785   Loss: 1.2868   Acc: 0.7003
# --------------------
# Epoch 47/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4255   Loss: 0.5673   Acc: 0.8505
# Validating [Done!]   Time: 6.3345   Loss: 1.4721   Acc: 0.6783
# --------------------
# Epoch 48/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4956   Loss: 0.5495   Acc: 0.8531
# Validating [Done!]   Time: 6.2753   Loss: 1.2673   Acc: 0.7126
# --------------------
# Epoch 49/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.3111   Loss: 0.5458   Acc: 0.8514
# Validating [Done!]   Time: 6.2743   Loss: 1.3698   Acc: 0.6962
# --------------------
# Epoch 50/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.2969   Loss: 0.5370   Acc: 0.8556
# Validating [Done!]   Time: 6.3101   Loss: 1.4057   Acc: 0.6829
#  + Saved checkpoint 'checkpoints/prob1c_1/E50_checkpoint.th'
# --------------------
# Epoch 51/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4759   Loss: 0.5535   Acc: 0.8508
# Validating [Done!]   Time: 6.3230   Loss: 1.2788   Acc: 0.7106
# --------------------
# Epoch 52/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5453   Loss: 0.5083   Acc: 0.8587
# Validating [Done!]   Time: 6.2815   Loss: 1.3555   Acc: 0.6926
# --------------------
# Epoch 53/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5496   Loss: 0.5207   Acc: 0.8625
# Validating [Done!]   Time: 6.3338   Loss: 1.3924   Acc: 0.6916
# --------------------
# Epoch 54/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5383   Loss: 0.5142   Acc: 0.8610
# Validating [Done!]   Time: 6.2708   Loss: 1.3130   Acc: 0.7054
# --------------------
# Epoch 55/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4643   Loss: 0.4980   Acc: 0.8661
# Validating [Done!]   Time: 6.2978   Loss: 1.3053   Acc: 0.7039
# --------------------
# Epoch 56/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4036   Loss: 0.5101   Acc: 0.8639
# Validating [Done!]   Time: 6.3428   Loss: 1.3054   Acc: 0.7100
# --------------------
# Epoch 57/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.3991   Loss: 0.5158   Acc: 0.8638
# Validating [Done!]   Time: 6.2671   Loss: 1.3864   Acc: 0.6844
# --------------------
# Epoch 58/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.5139   Loss: 0.5059   Acc: 0.8699
# Validating [Done!]   Time: 6.2772   Loss: 1.3185   Acc: 0.7049
# --------------------
# Epoch 59/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.4619   Loss: 0.5297   Acc: 0.8592
# Validating [Done!]   Time: 6.2746   Loss: 1.3161   Acc: 0.6849
# --------------------
# Epoch 60/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.2656   Loss: 0.4972   Acc: 0.8688
# Validating [Done!]   Time: 6.2745   Loss: 1.3690   Acc: 0.6942
#  + Saved checkpoint 'checkpoints/prob1c_1/E60_checkpoint.th'
# --------------------
# Epoch 61/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.3454   Loss: 0.4639   Acc: 0.8761
# Validating [Done!]   Time: 6.2852   Loss: 1.3278   Acc: 0.7008
# --------------------
# Epoch 62/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4734   Loss: 0.3926   Acc: 0.8958
# Validating [Done!]   Time: 6.2775   Loss: 1.0978   Acc: 0.7444
# --------------------
# Epoch 63/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5169   Loss: 0.3902   Acc: 0.8962
# Validating [Done!]   Time: 6.3007   Loss: 1.0399   Acc: 0.7469
# --------------------
# Epoch 64/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4640   Loss: 0.3378   Acc: 0.9081
# Validating [Done!]   Time: 6.3510   Loss: 1.0155   Acc: 0.7577
# --------------------
# Epoch 65/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3744   Loss: 0.3333   Acc: 0.9111
# Validating [Done!]   Time: 6.2815   Loss: 1.0165   Acc: 0.7480
# --------------------
# Epoch 66/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4056   Loss: 0.3372   Acc: 0.9090
# Validating [Done!]   Time: 6.2980   Loss: 1.0004   Acc: 0.7546
# --------------------
# Epoch 67/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3946   Loss: 0.3265   Acc: 0.9121
# Validating [Done!]   Time: 6.2850   Loss: 1.0002   Acc: 0.7556
# --------------------
# Epoch 68/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5228   Loss: 0.3276   Acc: 0.9143
# Validating [Done!]   Time: 6.2951   Loss: 1.0049   Acc: 0.7582
# --------------------
# Epoch 69/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5356   Loss: 0.3117   Acc: 0.9173
# Validating [Done!]   Time: 6.2968   Loss: 0.9974   Acc: 0.7567
# --------------------
# Epoch 70/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5824   Loss: 0.2905   Acc: 0.9243
# Validating [Done!]   Time: 6.2936   Loss: 0.9907   Acc: 0.7638
#  + Saved checkpoint 'checkpoints/prob1c_1/E70_checkpoint.th'
# --------------------
# Epoch 71/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4584   Loss: 0.3036   Acc: 0.9204
# Validating [Done!]   Time: 6.2943   Loss: 0.9825   Acc: 0.7674
# --------------------
# Epoch 72/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4074   Loss: 0.3073   Acc: 0.9189
# Validating [Done!]   Time: 6.3168   Loss: 0.9691   Acc: 0.7674
# --------------------
# Epoch 73/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.2607   Loss: 0.2866   Acc: 0.9243
# Validating [Done!]   Time: 6.2874   Loss: 0.9665   Acc: 0.7695
# --------------------
# Epoch 74/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3221   Loss: 0.3005   Acc: 0.9205
# Validating [Done!]   Time: 6.2665   Loss: 0.9695   Acc: 0.7643
# --------------------
# Epoch 75/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4418   Loss: 0.2858   Acc: 0.9247
# Validating [Done!]   Time: 6.2961   Loss: 0.9722   Acc: 0.7638
# --------------------
# Epoch 76/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4040   Loss: 0.2926   Acc: 0.9206
# Validating [Done!]   Time: 6.2784   Loss: 0.9822   Acc: 0.7608
# --------------------
# Epoch 77/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4558   Loss: 0.2899   Acc: 0.9239
# Validating [Done!]   Time: 6.2780   Loss: 0.9751   Acc: 0.7592
# --------------------
# Epoch 78/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4081   Loss: 0.2869   Acc: 0.9234
# Validating [Done!]   Time: 6.2850   Loss: 0.9500   Acc: 0.7731
# --------------------
# Epoch 79/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4740   Loss: 0.2893   Acc: 0.9231
# Validating [Done!]   Time: 6.2880   Loss: 0.9462   Acc: 0.7690
# --------------------
# Epoch 80/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3803   Loss: 0.3114   Acc: 0.9196
# Validating [Done!]   Time: 6.3780   Loss: 0.9627   Acc: 0.7618
#  + Saved checkpoint 'checkpoints/prob1c_1/E80_checkpoint.th'
# --------------------
# Epoch 81/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.2848   Loss: 0.2602   Acc: 0.9316
# Validating [Done!]   Time: 6.3122   Loss: 0.9625   Acc: 0.7643
# --------------------
# Epoch 82/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.2423   Loss: 0.2791   Acc: 0.9281
# Validating [Done!]   Time: 6.2603   Loss: 0.9419   Acc: 0.7731
# --------------------
# Epoch 83/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.1605   Loss: 0.2858   Acc: 0.9258
# Validating [Done!]   Time: 6.2664   Loss: 0.9439   Acc: 0.7715
# --------------------
# Epoch 84/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.1557   Loss: 0.2881   Acc: 0.9235
# Validating [Done!]   Time: 6.2443   Loss: 0.9377   Acc: 0.7746
# --------------------
# Epoch 85/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3251   Loss: 0.2712   Acc: 0.9304
# Validating [Done!]   Time: 6.2801   Loss: 0.9511   Acc: 0.7649
# --------------------
# Epoch 86/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3306   Loss: 0.2850   Acc: 0.9223
# Validating [Done!]   Time: 6.2976   Loss: 0.9541   Acc: 0.7664
# --------------------
# Epoch 87/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3474   Loss: 0.2764   Acc: 0.9254
# Validating [Done!]   Time: 6.2937   Loss: 0.9384   Acc: 0.7715
# --------------------
# Epoch 88/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5454   Loss: 0.2628   Acc: 0.9303
# Validating [Done!]   Time: 6.3558   Loss: 0.9318   Acc: 0.7695
# --------------------
# Epoch 89/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3935   Loss: 0.2772   Acc: 0.9293
# Validating [Done!]   Time: 6.2701   Loss: 0.9404   Acc: 0.7766
# --------------------
# Epoch 90/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.1752   Loss: 0.2608   Acc: 0.9334
# Validating [Done!]   Time: 6.2662   Loss: 0.9363   Acc: 0.7736
#  + Saved checkpoint 'checkpoints/prob1c_1/E90_checkpoint.th'
# --------------------
# Epoch 91/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3332   Loss: 0.2631   Acc: 0.9304
# Validating [Done!]   Time: 6.2925   Loss: 0.9358   Acc: 0.7731
# --------------------
# Epoch 92/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4832   Loss: 0.2655   Acc: 0.9272
# Validating [Done!]   Time: 6.2870   Loss: 0.9355   Acc: 0.7782
# --------------------
# Epoch 93/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3375   Loss: 0.2554   Acc: 0.9342
# Validating [Done!]   Time: 6.2766   Loss: 0.9501   Acc: 0.7720
# --------------------
# Epoch 94/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5697   Loss: 0.2811   Acc: 0.9245
# Validating [Done!]   Time: 6.2893   Loss: 0.9339   Acc: 0.7720
# --------------------
# Epoch 95/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3123   Loss: 0.2757   Acc: 0.9281
# Validating [Done!]   Time: 6.2758   Loss: 0.9337   Acc: 0.7669
# --------------------
# Epoch 96/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3851   Loss: 0.2458   Acc: 0.9324
# Validating [Done!]   Time: 6.3196   Loss: 0.9321   Acc: 0.7731
# --------------------
# Epoch 97/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4086   Loss: 0.2492   Acc: 0.9367
# Validating [Done!]   Time: 6.2618   Loss: 0.9271   Acc: 0.7725
# --------------------
# Epoch 98/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.2117   Loss: 0.2638   Acc: 0.9300
# Validating [Done!]   Time: 6.2517   Loss: 0.9390   Acc: 0.7710
# --------------------
# Epoch 99/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3194   Loss: 0.2585   Acc: 0.9310
# Validating [Done!]   Time: 6.2757   Loss: 0.9474   Acc: 0.7731
# --------------------
# Epoch 100/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4628   Loss: 0.2640   Acc: 0.9289
# Validating [Done!]   Time: 6.2962   Loss: 0.9612   Acc: 0.7679
#  + Saved checkpoint 'checkpoints/prob1c_1/E100_checkpoint.th'
# --------------------
# Epoch 101/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.0989   Loss: 0.2787   Acc: 0.9263
# Validating [Done!]   Time: 6.2629   Loss: 0.9456   Acc: 0.7736
# --------------------
# Epoch 102/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4408   Loss: 0.2552   Acc: 0.9318
# Validating [Done!]   Time: 6.2733   Loss: 0.9448   Acc: 0.7741
# --------------------
# Epoch 103/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.1322   Loss: 0.2420   Acc: 0.9349
# Validating [Done!]   Time: 6.2866   Loss: 0.9402   Acc: 0.7710
# --------------------
# Epoch 104/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4463   Loss: 0.2241   Acc: 0.9391
# Validating [Done!]   Time: 6.2922   Loss: 0.9435   Acc: 0.7710
# --------------------
# Epoch 105/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5354   Loss: 0.2503   Acc: 0.9329
# Validating [Done!]   Time: 6.3088   Loss: 0.9659   Acc: 0.7649
# --------------------
# Epoch 106/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4646   Loss: 0.2492   Acc: 0.9341
# Validating [Done!]   Time: 6.3088   Loss: 0.9312   Acc: 0.7695
# --------------------
# Epoch 107/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.5022   Loss: 0.2431   Acc: 0.9341
# Validating [Done!]   Time: 6.2876   Loss: 0.9409   Acc: 0.7725
# --------------------
# Epoch 108/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3389   Loss: 0.2436   Acc: 0.9367
# Validating [Done!]   Time: 6.2657   Loss: 0.9298   Acc: 0.7731
# --------------------
# Epoch 109/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.0816   Loss: 0.2356   Acc: 0.9368
# Validating [Done!]   Time: 6.2630   Loss: 0.9523   Acc: 0.7700
# --------------------
# Epoch 110/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3760   Loss: 0.2469   Acc: 0.9333
# Validating [Done!]   Time: 6.2854   Loss: 0.9292   Acc: 0.7725
#  + Saved checkpoint 'checkpoints/prob1c_1/E110_checkpoint.th'
# --------------------
# Epoch 111/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.1483   Loss: 0.2568   Acc: 0.9295
# Validating [Done!]   Time: 6.2690   Loss: 0.9356   Acc: 0.7720
# --------------------
# Epoch 112/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.2323   Loss: 0.2501   Acc: 0.9357
# Validating [Done!]   Time: 6.3039   Loss: 0.9383   Acc: 0.7679
# --------------------
# Epoch 113/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3357   Loss: 0.2474   Acc: 0.9328
# Validating [Done!]   Time: 6.2703   Loss: 0.9452   Acc: 0.7705
# --------------------
# Epoch 114/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3750   Loss: 0.2369   Acc: 0.9355
# Validating [Done!]   Time: 6.2852   Loss: 0.9405   Acc: 0.7782
# --------------------
# Epoch 115/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4453   Loss: 0.2474   Acc: 0.9350
# Validating [Done!]   Time: 6.2701   Loss: 0.9476   Acc: 0.7700
# --------------------
# Epoch 116/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4274   Loss: 0.2313   Acc: 0.9383
# Validating [Done!]   Time: 6.2617   Loss: 0.9481   Acc: 0.7705
# --------------------
# Epoch 117/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4233   Loss: 0.2340   Acc: 0.9336
# Validating [Done!]   Time: 6.2997   Loss: 0.9326   Acc: 0.7746
# --------------------
# Epoch 118/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3398   Loss: 0.2344   Acc: 0.9392
# Validating [Done!]   Time: 6.3477   Loss: 0.9346   Acc: 0.7720
# --------------------
# Epoch 119/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4690   Loss: 0.2364   Acc: 0.9376
# Validating [Done!]   Time: 6.2663   Loss: 0.9438   Acc: 0.7695
# --------------------
# Epoch 120/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4657   Loss: 0.2321   Acc: 0.9366
# Validating [Done!]   Time: 6.2728   Loss: 0.9393   Acc: 0.7633
#  + Saved checkpoint 'checkpoints/prob1c_1/E120_checkpoint.th'
# --------------------
# Epoch 121/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.3994   Loss: 0.2380   Acc: 0.9382
# Validating [Done!]   Time: 6.2993   Loss: 0.9382   Acc: 0.7700
# --------------------
# Epoch 122/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4053   Loss: 0.2316   Acc: 0.9382
# Validating [Done!]   Time: 6.2646   Loss: 0.9392   Acc: 0.7664
# --------------------
# Epoch 123/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2152   Loss: 0.2451   Acc: 0.9343
# Validating [Done!]   Time: 6.2718   Loss: 0.9460   Acc: 0.7725
# --------------------
# Epoch 124/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4650   Loss: 0.2299   Acc: 0.9415
# Validating [Done!]   Time: 6.2711   Loss: 0.9388   Acc: 0.7690
# --------------------
# Epoch 125/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3396   Loss: 0.2395   Acc: 0.9391
# Validating [Done!]   Time: 6.2749   Loss: 0.9368   Acc: 0.7772
# --------------------
# Epoch 126/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4578   Loss: 0.2205   Acc: 0.9408
# Validating [Done!]   Time: 6.2752   Loss: 0.9389   Acc: 0.7690
# --------------------
# Epoch 127/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.1820   Loss: 0.2410   Acc: 0.9351
# Validating [Done!]   Time: 6.2805   Loss: 0.9400   Acc: 0.7700
# --------------------
# Epoch 128/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3350   Loss: 0.2291   Acc: 0.9400
# Validating [Done!]   Time: 6.3106   Loss: 0.9311   Acc: 0.7690
# --------------------
# Epoch 129/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2445   Loss: 0.2396   Acc: 0.9372
# Validating [Done!]   Time: 6.2792   Loss: 0.9395   Acc: 0.7674
# --------------------
# Epoch 130/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2822   Loss: 0.2144   Acc: 0.9419
# Validating [Done!]   Time: 6.3021   Loss: 0.9423   Acc: 0.7705
#  + Saved checkpoint 'checkpoints/prob1c_1/E130_checkpoint.th'
# --------------------
# Epoch 131/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2527   Loss: 0.2379   Acc: 0.9380
# Validating [Done!]   Time: 6.2812   Loss: 0.9320   Acc: 0.7700
# --------------------
# Epoch 132/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.1534   Loss: 0.2295   Acc: 0.9386
# Validating [Done!]   Time: 6.2653   Loss: 0.9290   Acc: 0.7705
# --------------------
# Epoch 133/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3131   Loss: 0.2356   Acc: 0.9380
# Validating [Done!]   Time: 6.2682   Loss: 0.9335   Acc: 0.7710
# --------------------
# Epoch 134/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4640   Loss: 0.2243   Acc: 0.9403
# Validating [Done!]   Time: 6.2713   Loss: 0.9421   Acc: 0.7679
# --------------------
# Epoch 135/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2294   Loss: 0.2120   Acc: 0.9446
# Validating [Done!]   Time: 6.2765   Loss: 0.9433   Acc: 0.7679
# --------------------
# Epoch 136/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3133   Loss: 0.2248   Acc: 0.9409
# Validating [Done!]   Time: 6.2816   Loss: 0.9253   Acc: 0.7705
# --------------------
# Epoch 137/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3725   Loss: 0.2317   Acc: 0.9415
# Validating [Done!]   Time: 6.2446   Loss: 0.9290   Acc: 0.7700
# --------------------
# Epoch 138/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.1822   Loss: 0.2222   Acc: 0.9421
# Validating [Done!]   Time: 6.2902   Loss: 0.9232   Acc: 0.7731
# --------------------
# Epoch 139/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4324   Loss: 0.2173   Acc: 0.9409
# Validating [Done!]   Time: 6.2667   Loss: 0.9313   Acc: 0.7705
# --------------------
# Epoch 140/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.1311   Loss: 0.2307   Acc: 0.9367
# Validating [Done!]   Time: 6.2718   Loss: 0.9247   Acc: 0.7741
#  + Saved checkpoint 'checkpoints/prob1c_1/E140_checkpoint.th'
# --------------------
# Epoch 141/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3213   Loss: 0.2270   Acc: 0.9388
# Validating [Done!]   Time: 6.2878   Loss: 0.9283   Acc: 0.7741
# --------------------
# Epoch 142/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3271   Loss: 0.2105   Acc: 0.9449
# Validating [Done!]   Time: 6.2760   Loss: 0.9208   Acc: 0.7741
# --------------------
# Epoch 143/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2253   Loss: 0.2380   Acc: 0.9379
# Validating [Done!]   Time: 6.2961   Loss: 0.9293   Acc: 0.7761
# --------------------
# Epoch 144/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4969   Loss: 0.2302   Acc: 0.9388
# Validating [Done!]   Time: 6.2847   Loss: 0.9288   Acc: 0.7715
# --------------------
# Epoch 145/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3224   Loss: 0.2422   Acc: 0.9329
# Validating [Done!]   Time: 6.3055   Loss: 0.9274   Acc: 0.7756
# --------------------
# Epoch 146/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.1787   Loss: 0.2197   Acc: 0.9430
# Validating [Done!]   Time: 6.2855   Loss: 0.9282   Acc: 0.7746
# --------------------
# Epoch 147/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3567   Loss: 0.2357   Acc: 0.9368
# Validating [Done!]   Time: 6.2923   Loss: 0.9354   Acc: 0.7741
# --------------------
# Epoch 148/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4782   Loss: 0.2390   Acc: 0.9337
# Validating [Done!]   Time: 6.3437   Loss: 0.9212   Acc: 0.7756
# --------------------
# Epoch 149/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2902   Loss: 0.2131   Acc: 0.9437
# Validating [Done!]   Time: 6.2653   Loss: 0.9176   Acc: 0.7731
# --------------------
# Epoch 150/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2898   Loss: 0.2171   Acc: 0.9425
# Validating [Done!]   Time: 6.3037   Loss: 0.9286   Acc: 0.7746
#  + Saved checkpoint 'checkpoints/prob1c_1/E150_checkpoint.th'
# --------------------
# Epoch 151/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4959   Loss: 0.2189   Acc: 0.9416
# Validating [Done!]   Time: 6.2866   Loss: 0.9292   Acc: 0.7736
# --------------------
# Epoch 152/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3924   Loss: 0.2162   Acc: 0.9415
# Validating [Done!]   Time: 6.3084   Loss: 0.9236   Acc: 0.7746
# --------------------
# Epoch 153/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4581   Loss: 0.2265   Acc: 0.9413
# Validating [Done!]   Time: 6.2655   Loss: 0.9323   Acc: 0.7669
# --------------------
# Epoch 154/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.1773   Loss: 0.2172   Acc: 0.9425
# Validating [Done!]   Time: 6.2665   Loss: 0.9358   Acc: 0.7705
# --------------------
# Epoch 155/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3783   Loss: 0.2178   Acc: 0.9446
# Validating [Done!]   Time: 6.2853   Loss: 0.9332   Acc: 0.7751
# --------------------
# Epoch 156/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5381   Loss: 0.2209   Acc: 0.9407
# Validating [Done!]   Time: 6.2772   Loss: 0.9447   Acc: 0.7715
# --------------------
# Epoch 157/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3241   Loss: 0.2201   Acc: 0.9388
# Validating [Done!]   Time: 6.2693   Loss: 0.9274   Acc: 0.7710
# --------------------
# Epoch 158/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.1406   Loss: 0.2101   Acc: 0.9452
# Validating [Done!]   Time: 6.2537   Loss: 0.9315   Acc: 0.7659
# --------------------
# Epoch 159/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2644   Loss: 0.2323   Acc: 0.9376
# Validating [Done!]   Time: 6.2887   Loss: 0.9317   Acc: 0.7690
# --------------------
# Epoch 160/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5435   Loss: 0.2375   Acc: 0.9368
# Validating [Done!]   Time: 6.2678   Loss: 0.9239   Acc: 0.7684
#  + Saved checkpoint 'checkpoints/prob1c_1/E160_checkpoint.th'
# --------------------
# Epoch 161/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2599   Loss: 0.2286   Acc: 0.9370
# Validating [Done!]   Time: 6.2613   Loss: 0.9263   Acc: 0.7720
# --------------------
# Epoch 162/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2811   Loss: 0.2238   Acc: 0.9400
# Validating [Done!]   Time: 6.2834   Loss: 0.9341   Acc: 0.7736
# --------------------
# Epoch 163/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.5439   Loss: 0.2176   Acc: 0.9432
# Validating [Done!]   Time: 6.2879   Loss: 0.9221   Acc: 0.7720
# --------------------
# Epoch 164/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2538   Loss: 0.2027   Acc: 0.9461
# Validating [Done!]   Time: 6.2616   Loss: 0.9338   Acc: 0.7725
# --------------------
# Epoch 165/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3672   Loss: 0.2288   Acc: 0.9396
# Validating [Done!]   Time: 6.2786   Loss: 0.9381   Acc: 0.7720
# --------------------
# Epoch 166/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4567   Loss: 0.2355   Acc: 0.9396
# Validating [Done!]   Time: 6.2953   Loss: 0.9335   Acc: 0.7684
# --------------------
# Epoch 167/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2405   Loss: 0.2298   Acc: 0.9399
# Validating [Done!]   Time: 6.2904   Loss: 0.9275   Acc: 0.7695
# --------------------
# Epoch 168/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3374   Loss: 0.2198   Acc: 0.9433
# Validating [Done!]   Time: 6.2894   Loss: 0.9304   Acc: 0.7710
# --------------------
# Epoch 169/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4703   Loss: 0.2345   Acc: 0.9363
# Validating [Done!]   Time: 6.3029   Loss: 0.9365   Acc: 0.7679
# --------------------
# Epoch 170/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2569   Loss: 0.2244   Acc: 0.9395
# Validating [Done!]   Time: 6.2868   Loss: 0.9302   Acc: 0.7674
#  + Saved checkpoint 'checkpoints/prob1c_1/E170_checkpoint.th'
# --------------------
# Epoch 171/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4269   Loss: 0.2087   Acc: 0.9428
# Validating [Done!]   Time: 6.2734   Loss: 0.9390   Acc: 0.7695
# --------------------
# Epoch 172/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4799   Loss: 0.2266   Acc: 0.9380
# Validating [Done!]   Time: 6.3258   Loss: 0.9286   Acc: 0.7731
# --------------------
# Epoch 173/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4842   Loss: 0.2274   Acc: 0.9390
# Validating [Done!]   Time: 6.2765   Loss: 0.9295   Acc: 0.7715
# --------------------
# Epoch 174/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2741   Loss: 0.2273   Acc: 0.9396
# Validating [Done!]   Time: 6.2708   Loss: 0.9335   Acc: 0.7700
# --------------------
# Epoch 175/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2870   Loss: 0.2263   Acc: 0.9396
# Validating [Done!]   Time: 6.2832   Loss: 0.9394   Acc: 0.7664
# --------------------
# Epoch 176/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4510   Loss: 0.2155   Acc: 0.9429
# Validating [Done!]   Time: 6.3074   Loss: 0.9363   Acc: 0.7679
# --------------------
# Epoch 177/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4978   Loss: 0.2192   Acc: 0.9395
# Validating [Done!]   Time: 6.2863   Loss: 0.9295   Acc: 0.7695
# --------------------
# Epoch 178/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3256   Loss: 0.2086   Acc: 0.9446
# Validating [Done!]   Time: 6.2951   Loss: 0.9424   Acc: 0.7674
# --------------------
# Epoch 179/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4040   Loss: 0.2133   Acc: 0.9450
# Validating [Done!]   Time: 6.3059   Loss: 0.9327   Acc: 0.7746
# --------------------
# Epoch 180/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.2728   Loss: 0.2225   Acc: 0.9400
# Validating [Done!]   Time: 6.2719   Loss: 0.9333   Acc: 0.7736
#  + Saved checkpoint 'checkpoints/prob1c_1/E180_checkpoint.th'
# --------------------
# Epoch 181/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.3359   Loss: 0.2198   Acc: 0.9412
# Validating [Done!]   Time: 6.2832   Loss: 0.9340   Acc: 0.7710
# --------------------
# Epoch 182/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5361   Loss: 0.2006   Acc: 0.9471
# Validating [Done!]   Time: 6.2644   Loss: 0.9308   Acc: 0.7654
# --------------------
# Epoch 183/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.3615   Loss: 0.2197   Acc: 0.9421
# Validating [Done!]   Time: 6.3812   Loss: 0.9319   Acc: 0.7664
# --------------------
# Epoch 184/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5717   Loss: 0.2343   Acc: 0.9366
# Validating [Done!]   Time: 6.2806   Loss: 0.9270   Acc: 0.7725
# --------------------
# Epoch 185/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.4441   Loss: 0.2357   Acc: 0.9355
# Validating [Done!]   Time: 6.2690   Loss: 0.9237   Acc: 0.7700
# --------------------
# Epoch 186/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.4090   Loss: 0.2101   Acc: 0.9453
# Validating [Done!]   Time: 6.2919   Loss: 0.9333   Acc: 0.7725
# --------------------
# Epoch 187/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.4637   Loss: 0.2225   Acc: 0.9413
# Validating [Done!]   Time: 6.2822   Loss: 0.9421   Acc: 0.7720
# --------------------
# Epoch 188/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.3341   Loss: 0.2124   Acc: 0.9417
# Validating [Done!]   Time: 6.2859   Loss: 0.9374   Acc: 0.7725
# --------------------
# Epoch 189/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5764   Loss: 0.2020   Acc: 0.9434
# Validating [Done!]   Time: 6.3523   Loss: 0.9282   Acc: 0.7669
# --------------------
# Epoch 190/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5888   Loss: 0.2267   Acc: 0.9378
# Validating [Done!]   Time: 6.2852   Loss: 0.9292   Acc: 0.7710
#  + Saved checkpoint 'checkpoints/prob1c_1/E190_checkpoint.th'
# --------------------
# Epoch 191/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.3363   Loss: 0.2193   Acc: 0.9392
# Validating [Done!]   Time: 6.2680   Loss: 0.9454   Acc: 0.7659
# --------------------
# Epoch 192/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.2668   Loss: 0.2335   Acc: 0.9394
# Validating [Done!]   Time: 6.3111   Loss: 0.9320   Acc: 0.7720
# --------------------
# Epoch 193/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5116   Loss: 0.2345   Acc: 0.9384
# Validating [Done!]   Time: 6.3023   Loss: 0.9270   Acc: 0.7731
# --------------------
# Epoch 194/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5116   Loss: 0.2053   Acc: 0.9446
# Validating [Done!]   Time: 6.2859   Loss: 0.9192   Acc: 0.7695
# --------------------
# Epoch 195/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.2589   Loss: 0.2058   Acc: 0.9461
# Validating [Done!]   Time: 6.2602   Loss: 0.9299   Acc: 0.7690
# --------------------
# Epoch 196/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.3432   Loss: 0.2517   Acc: 0.9359
# Validating [Done!]   Time: 6.2915   Loss: 0.9352   Acc: 0.7674
# --------------------
# Epoch 197/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.4974   Loss: 0.2294   Acc: 0.9392
# Validating [Done!]   Time: 6.3247   Loss: 0.9242   Acc: 0.7725
# --------------------
# Epoch 198/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.3337   Loss: 0.2336   Acc: 0.9375
# Validating [Done!]   Time: 6.3212   Loss: 0.9281   Acc: 0.7705
# --------------------
# Epoch 199/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5420   Loss: 0.2214   Acc: 0.9415
# Validating [Done!]   Time: 6.2859   Loss: 0.9358   Acc: 0.7695
# --------------------
# Epoch 200/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5081   Loss: 0.2131   Acc: 0.9432
# Validating [Done!]   Time: 6.2791   Loss: 0.9273   Acc: 0.7720
# --------------------
#  + Saved checkpoint 'checkpoints/prob1c_1/final_model.th'
# Training complete in 275m 38s
# Best val Acc: 0.778176

# %% [markdown]
# _Note: the following snippet was copied from the actual console output that included all 200 epochs. Here the output is shortened for brevity, but still illustrates the learning rate decay as well as shows the first and last epoch._
# ```
# Training model...
# ====================
# Epoch 1/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.6766   Loss: 3.9958   Acc: 0.0961
# Validating [Done!]   Time: 6.2765   Loss: 3.3706   Acc: 0.1870
# --------------------
# ...
# --------------------
# Epoch 62/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.4734   Loss: 0.3926   Acc: 0.8958
# Validating [Done!]   Time: 6.2775   Loss: 1.0978   Acc: 0.7444
# --------------------
# ...
# --------------------
# Epoch 122/200 (lr = 1.000e-04)
# Training [Done!]   Time: 76.4053   Loss: 0.2316   Acc: 0.9382
# Validating [Done!]   Time: 6.2646   Loss: 0.9392   Acc: 0.7664
# --------------------
# ...
# --------------------
# Epoch 182/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5361   Loss: 0.2006   Acc: 0.9471
# Validating [Done!]   Time: 6.2644   Loss: 0.9308   Acc: 0.7654
# --------------------
# ...
# --------------------
# Epoch 200/200 (lr = 1.000e-05)
# Training [Done!]   Time: 76.5081   Loss: 0.2131   Acc: 0.9432
# Validating [Done!]   Time: 6.2791   Loss: 0.9273   Acc: 0.7720
# --------------------
#  + Saved checkpoint 'checkpoints/prob1c_1/final_model.th'
# Training complete in 275m 38s
# Best val Acc: 0.778176
# ```

# %%
prob_name = 'prob1c_2'
save_epochs = 10
history = {}

##### PART 2: LR = 0.1
# for this part, we set initial training rate to 0.1
# but will use the same decay schedule
lr_init = 0.1

# prepare the pre-trained model
model_ft = models.resnet50(pretrained=True)
num_ftrs = model_ft.fc.in_features
# change the output layer to match number of new classes
model_ft.fc = nn.Linear(num_ftrs, num_classes)

# for checkpoints (save/load dir)
start_epoch = 0
save_dir = os.path.join('checkpoints',prob_name)
if not os.path.isdir(save_dir): os.mkdir(save_dir) # create save_dir
# model_ft, history = load_checkpoint(model_ft, save_dir, start_epoch) # uncomment to load model

# move model to the GPU
model_ft = model_ft.to(device)
cudnn.benchmark = True

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=lr_init, momentum=momentum)

# Decay learning rate per hyperparameters above
lr_scheduler_ft = torch.optim.lr_scheduler.MultiStepLR(optimizer_ft,
                                                      milestones=lr_epochs, 
                                                      gamma=lr_decay)#,
lr_scheduler_ft.last_epoch = start_epoch - 1

model_ft, history = train_model(model_ft, criterion, optimizer_ft, lr_scheduler_ft,
                                num_epochs=num_epochs, start_epoch=start_epoch, 
                                save_epochs=save_epochs, save_dir=save_dir, 
                                history=history, verbose=1)
# Out:
# Training model...
# ====================
# Epoch 1/200 (lr = 1.000e-01)
# Training [Done!]   Time: 74.2095   Loss: 4.7203   Acc: 0.0161
# Validating [Done!]   Time: 6.1948   Loss: 4.4782   Acc: 0.0179
# --------------------
# Epoch 2/200 (lr = 1.000e-01)
# Training [Done!]   Time: 74.0995   Loss: 4.4563   Acc: 0.0220
# Validating [Done!]   Time: 6.1807   Loss: 4.3010   Acc: 0.0256
# --------------------
# Epoch 3/200 (lr = 1.000e-01)
# Training [Done!]   Time: 73.9140   Loss: 4.3595   Acc: 0.0249
# Validating [Done!]   Time: 6.1516   Loss: 4.3296   Acc: 0.0225
# --------------------
# Epoch 4/200 (lr = 1.000e-01)
# Training [Done!]   Time: 74.0337   Loss: 4.2961   Acc: 0.0305
# Validating [Done!]   Time: 6.1748   Loss: 4.2086   Acc: 0.0364
# --------------------
# Epoch 5/200 (lr = 1.000e-01)
# Training [Done!]   Time: 74.4816   Loss: 4.2759   Acc: 0.0287
# Validating [Done!]   Time: 6.1680   Loss: 4.1738   Acc: 0.0374
# --------------------
# Epoch 6/200 (lr = 1.000e-01)
# Training [Done!]   Time: 74.3997   Loss: 4.2103   Acc: 0.0368
# Validating [Done!]   Time: 6.1744   Loss: 4.1110   Acc: 0.0492
# --------------------
# Epoch 7/200 (lr = 1.000e-01)
# Training [Done!]   Time: 74.7345   Loss: 4.1314   Acc: 0.0454
# Validating [Done!]   Time: 6.2025   Loss: 3.9973   Acc: 0.0661
# --------------------
# Epoch 8/200 (lr = 1.000e-01)
# Training [Done!]   Time: 74.8620   Loss: 4.0507   Acc: 0.0572
# Validating [Done!]   Time: 6.2633   Loss: 3.9437   Acc: 0.0681
# --------------------
# Epoch 9/200 (lr = 1.000e-01)
# Training [Done!]   Time: 74.9200   Loss: 3.9824   Acc: 0.0711
# Validating [Done!]   Time: 6.2004   Loss: 3.8085   Acc: 0.0902
# --------------------
# Epoch 10/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.2235   Loss: 3.8890   Acc: 0.0812
# Validating [Done!]   Time: 6.2107   Loss: 3.7815   Acc: 0.0963
#  + Saved checkpoint 'checkpoints/prob1c_2/E10_checkpoint.th'
# --------------------
# Epoch 11/200 (lr = 1.000e-01)
# Training [Done!]   Time: 74.9571   Loss: 3.8205   Acc: 0.0943
# Validating [Done!]   Time: 6.1923   Loss: 3.7821   Acc: 0.0989
# --------------------
# Epoch 12/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.3015   Loss: 3.7231   Acc: 0.1122
# Validating [Done!]   Time: 6.2350   Loss: 3.5928   Acc: 0.1281
# --------------------
# Epoch 13/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.1573   Loss: 3.6073   Acc: 0.1296
# Validating [Done!]   Time: 6.2065   Loss: 3.6901   Acc: 0.1286
# --------------------
# Epoch 14/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.4452   Loss: 3.5496   Acc: 0.1386
# Validating [Done!]   Time: 6.2175   Loss: 3.4187   Acc: 0.1670
# --------------------
# Epoch 15/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.3279   Loss: 3.4432   Acc: 0.1622
# Validating [Done!]   Time: 6.2052   Loss: 3.3714   Acc: 0.1701
# --------------------
# Epoch 16/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.3845   Loss: 3.3541   Acc: 0.1815
# Validating [Done!]   Time: 6.2387   Loss: 3.1039   Acc: 0.2208
# --------------------
# Epoch 17/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.6393   Loss: 3.2598   Acc: 0.1910
# Validating [Done!]   Time: 6.2967   Loss: 3.0504   Acc: 0.2310
# --------------------
# Epoch 18/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.6462   Loss: 3.1759   Acc: 0.2127
# Validating [Done!]   Time: 6.2356   Loss: 3.1786   Acc: 0.2275
# --------------------
# Epoch 19/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.5517   Loss: 3.0928   Acc: 0.2228
# Validating [Done!]   Time: 6.2396   Loss: 3.0963   Acc: 0.2321
# --------------------
# Epoch 20/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.7803   Loss: 3.0409   Acc: 0.2328
# Validating [Done!]   Time: 6.2248   Loss: 2.9572   Acc: 0.2418
#  + Saved checkpoint 'checkpoints/prob1c_2/E20_checkpoint.th'
# --------------------
# Epoch 21/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.6362   Loss: 2.9536   Acc: 0.2477
# Validating [Done!]   Time: 6.2283   Loss: 2.9939   Acc: 0.2505
# --------------------
# Epoch 22/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.7710   Loss: 2.8862   Acc: 0.2686
# Validating [Done!]   Time: 6.2515   Loss: 2.8062   Acc: 0.2761
# --------------------
# Epoch 23/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.7025   Loss: 2.8200   Acc: 0.2809
# Validating [Done!]   Time: 6.2077   Loss: 2.7525   Acc: 0.2894
# --------------------
# Epoch 24/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.4440   Loss: 2.7474   Acc: 0.3009
# Validating [Done!]   Time: 6.2162   Loss: 2.6979   Acc: 0.3171
# --------------------
# Epoch 25/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.6056   Loss: 2.7121   Acc: 0.3042
# Validating [Done!]   Time: 6.2469   Loss: 2.7156   Acc: 0.3186
# --------------------
# Epoch 26/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.8092   Loss: 2.6493   Acc: 0.3136
# Validating [Done!]   Time: 6.2276   Loss: 2.5061   Acc: 0.3402
# --------------------
# Epoch 27/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.6713   Loss: 2.5677   Acc: 0.3328
# Validating [Done!]   Time: 6.2219   Loss: 2.5258   Acc: 0.3438
# --------------------
# Epoch 28/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.6273   Loss: 2.5009   Acc: 0.3469
# Validating [Done!]   Time: 6.2360   Loss: 2.6018   Acc: 0.3268
# --------------------
# Epoch 29/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.7604   Loss: 2.4614   Acc: 0.3627
# Validating [Done!]   Time: 6.2110   Loss: 2.3803   Acc: 0.3760
# --------------------
# Epoch 30/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.5101   Loss: 2.4410   Acc: 0.3676
# Validating [Done!]   Time: 6.2182   Loss: 2.5131   Acc: 0.3776
#  + Saved checkpoint 'checkpoints/prob1c_2/E30_checkpoint.th'
# --------------------
# Epoch 31/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.6774   Loss: 2.3842   Acc: 0.3793
# Validating [Done!]   Time: 6.2397   Loss: 2.6083   Acc: 0.3422
# --------------------
# Epoch 32/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.8203   Loss: 2.3145   Acc: 0.3992
# Validating [Done!]   Time: 6.2169   Loss: 2.3982   Acc: 0.3832
# --------------------
# Epoch 33/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.4597   Loss: 2.2664   Acc: 0.4091
# Validating [Done!]   Time: 6.2688   Loss: 2.4627   Acc: 0.3755
# --------------------
# Epoch 34/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.7566   Loss: 2.2178   Acc: 0.4192
# Validating [Done!]   Time: 6.2470   Loss: 2.2922   Acc: 0.4098
# --------------------
# Epoch 35/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.9055   Loss: 2.1669   Acc: 0.4287
# Validating [Done!]   Time: 6.2727   Loss: 2.2384   Acc: 0.4093
# --------------------
# Epoch 36/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.6043   Loss: 2.1226   Acc: 0.4442
# Validating [Done!]   Time: 6.2579   Loss: 2.4003   Acc: 0.4062
# --------------------
# Epoch 37/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.7216   Loss: 2.0936   Acc: 0.4535
# Validating [Done!]   Time: 6.2432   Loss: 2.3018   Acc: 0.4047
# --------------------
# Epoch 38/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.7925   Loss: 2.0283   Acc: 0.4641
# Validating [Done!]   Time: 6.2527   Loss: 2.1663   Acc: 0.4452
# --------------------
# Epoch 39/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.8811   Loss: 1.9808   Acc: 0.4758
# Validating [Done!]   Time: 6.2448   Loss: 2.3135   Acc: 0.4232
# --------------------
# Epoch 40/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.6737   Loss: 1.9208   Acc: 0.4902
# Validating [Done!]   Time: 6.2288   Loss: 2.2021   Acc: 0.4447
#  + Saved checkpoint 'checkpoints/prob1c_2/E40_checkpoint.th'
# --------------------
# Epoch 41/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.5447   Loss: 1.8904   Acc: 0.4931
# Validating [Done!]   Time: 6.2518   Loss: 2.1327   Acc: 0.4513
# --------------------
# Epoch 42/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.7762   Loss: 1.8237   Acc: 0.5158
# Validating [Done!]   Time: 6.2603   Loss: 2.1206   Acc: 0.4749
# --------------------
# Epoch 43/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.9348   Loss: 1.7956   Acc: 0.5221
# Validating [Done!]   Time: 6.2475   Loss: 2.0058   Acc: 0.4857
# --------------------
# Epoch 44/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.6475   Loss: 1.7332   Acc: 0.5354
# Validating [Done!]   Time: 6.2339   Loss: 2.1565   Acc: 0.4682
# --------------------
# Epoch 45/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.7526   Loss: 1.7193   Acc: 0.5330
# Validating [Done!]   Time: 6.2413   Loss: 2.0969   Acc: 0.4887
# --------------------
# Epoch 46/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.6654   Loss: 1.6678   Acc: 0.5449
# Validating [Done!]   Time: 6.2233   Loss: 2.0438   Acc: 0.4908
# --------------------
# Epoch 47/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.8495   Loss: 1.6199   Acc: 0.5626
# Validating [Done!]   Time: 6.2651   Loss: 1.9974   Acc: 0.5031
# --------------------
# Epoch 48/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.7952   Loss: 1.6075   Acc: 0.5742
# Validating [Done!]   Time: 6.2568   Loss: 1.9960   Acc: 0.4959
# --------------------
# Epoch 49/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.7201   Loss: 1.5724   Acc: 0.5743
# Validating [Done!]   Time: 6.2377   Loss: 2.3573   Acc: 0.4483
# --------------------
# Epoch 50/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.8956   Loss: 1.5395   Acc: 0.5900
# Validating [Done!]   Time: 6.2505   Loss: 2.0107   Acc: 0.5231
#  + Saved checkpoint 'checkpoints/prob1c_2/E50_checkpoint.th'
# --------------------
# Epoch 51/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.8916   Loss: 1.5163   Acc: 0.5877
# Validating [Done!]   Time: 6.2606   Loss: 1.8676   Acc: 0.5384
# --------------------
# Epoch 52/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.8702   Loss: 1.4685   Acc: 0.6016
# Validating [Done!]   Time: 6.2605   Loss: 2.0447   Acc: 0.5072
# --------------------
# Epoch 53/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.8452   Loss: 1.4232   Acc: 0.6165
# Validating [Done!]   Time: 6.2597   Loss: 1.9569   Acc: 0.5164
# --------------------
# Epoch 54/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.6663   Loss: 1.3759   Acc: 0.6299
# Validating [Done!]   Time: 6.2488   Loss: 1.9929   Acc: 0.5133
# --------------------
# Epoch 55/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.8796   Loss: 1.3067   Acc: 0.6439
# Validating [Done!]   Time: 6.2455   Loss: 2.0112   Acc: 0.5061
# --------------------
# Epoch 56/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.7256   Loss: 1.3216   Acc: 0.6425
# Validating [Done!]   Time: 6.2606   Loss: 1.8663   Acc: 0.5543
# --------------------
# Epoch 57/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.8811   Loss: 1.2729   Acc: 0.6551
# Validating [Done!]   Time: 6.2481   Loss: 2.0278   Acc: 0.5241
# --------------------
# Epoch 58/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.8674   Loss: 1.2708   Acc: 0.6515
# Validating [Done!]   Time: 6.2366   Loss: 1.9893   Acc: 0.5266
# --------------------
# Epoch 59/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.7792   Loss: 1.2629   Acc: 0.6584
# Validating [Done!]   Time: 6.2393   Loss: 1.8323   Acc: 0.5456
# --------------------
# Epoch 60/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.9171   Loss: 1.1800   Acc: 0.6831
# Validating [Done!]   Time: 6.2515   Loss: 1.8899   Acc: 0.5625
#  + Saved checkpoint 'checkpoints/prob1c_2/E60_checkpoint.th'
# --------------------
# Epoch 61/200 (lr = 1.000e-01)
# Training [Done!]   Time: 75.9509   Loss: 1.2018   Acc: 0.6796
# Validating [Done!]   Time: 6.2835   Loss: 1.9067   Acc: 0.5435
# --------------------
# Epoch 62/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.8188   Loss: 0.9828   Acc: 0.7429
# Validating [Done!]   Time: 6.2297   Loss: 1.4431   Acc: 0.6429
# --------------------
# Epoch 63/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.8944   Loss: 0.8470   Acc: 0.7756
# Validating [Done!]   Time: 6.2701   Loss: 1.4167   Acc: 0.6491
# --------------------
# Epoch 64/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9527   Loss: 0.8292   Acc: 0.7826
# Validating [Done!]   Time: 6.2519   Loss: 1.4211   Acc: 0.6455
# --------------------
# Epoch 65/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.8137   Loss: 0.7845   Acc: 0.7970
# Validating [Done!]   Time: 6.2334   Loss: 1.4341   Acc: 0.6506
# --------------------
# Epoch 66/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7718   Loss: 0.7530   Acc: 0.7987
# Validating [Done!]   Time: 6.2582   Loss: 1.4426   Acc: 0.6562
# --------------------
# Epoch 67/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9823   Loss: 0.7358   Acc: 0.8042
# Validating [Done!]   Time: 6.2683   Loss: 1.4550   Acc: 0.6522
# --------------------
# Epoch 68/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7235   Loss: 0.7656   Acc: 0.8005
# Validating [Done!]   Time: 6.2515   Loss: 1.4260   Acc: 0.6624
# --------------------
# Epoch 69/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.8397   Loss: 0.7395   Acc: 0.8059
# Validating [Done!]   Time: 6.2639   Loss: 1.4295   Acc: 0.6562
# --------------------
# Epoch 70/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9870   Loss: 0.7209   Acc: 0.8120
# Validating [Done!]   Time: 6.2448   Loss: 1.4312   Acc: 0.6603
#  + Saved checkpoint 'checkpoints/prob1c_2/E70_checkpoint.th'
# --------------------
# Epoch 71/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.8775   Loss: 0.7136   Acc: 0.8132
# Validating [Done!]   Time: 6.2772   Loss: 1.4569   Acc: 0.6522
# --------------------
# Epoch 72/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.6435   Loss: 0.6942   Acc: 0.8149
# Validating [Done!]   Time: 6.2434   Loss: 1.4407   Acc: 0.6619
# --------------------
# Epoch 73/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.8098   Loss: 0.6722   Acc: 0.8245
# Validating [Done!]   Time: 6.2596   Loss: 1.4256   Acc: 0.6644
# --------------------
# Epoch 74/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9430   Loss: 0.6848   Acc: 0.8224
# Validating [Done!]   Time: 6.2560   Loss: 1.4753   Acc: 0.6624
# --------------------
# Epoch 75/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7408   Loss: 0.6847   Acc: 0.8138
# Validating [Done!]   Time: 6.2536   Loss: 1.4486   Acc: 0.6726
# --------------------
# Epoch 76/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.8460   Loss: 0.6862   Acc: 0.8195
# Validating [Done!]   Time: 6.2794   Loss: 1.4689   Acc: 0.6660
# --------------------
# Epoch 77/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.0145   Loss: 0.6429   Acc: 0.8285
# Validating [Done!]   Time: 6.2812   Loss: 1.4654   Acc: 0.6593
# --------------------
# Epoch 78/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7435   Loss: 0.6496   Acc: 0.8307
# Validating [Done!]   Time: 6.2449   Loss: 1.4776   Acc: 0.6629
# --------------------
# Epoch 79/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.6489   Loss: 0.6295   Acc: 0.8344
# Validating [Done!]   Time: 6.2729   Loss: 1.4903   Acc: 0.6660
# --------------------
# Epoch 80/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.8998   Loss: 0.6326   Acc: 0.8336
# Validating [Done!]   Time: 6.2453   Loss: 1.4929   Acc: 0.6573
#  + Saved checkpoint 'checkpoints/prob1c_2/E80_checkpoint.th'
# --------------------
# Epoch 81/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.0057   Loss: 0.6327   Acc: 0.8339
# Validating [Done!]   Time: 6.2512   Loss: 1.4591   Acc: 0.6655
# --------------------
# Epoch 82/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.8858   Loss: 0.6205   Acc: 0.8363
# Validating [Done!]   Time: 6.3200   Loss: 1.4727   Acc: 0.6588
# --------------------
# Epoch 83/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7478   Loss: 0.6381   Acc: 0.8311
# Validating [Done!]   Time: 6.2394   Loss: 1.4886   Acc: 0.6639
# --------------------
# Epoch 84/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7250   Loss: 0.5947   Acc: 0.8409
# Validating [Done!]   Time: 6.2483   Loss: 1.4862   Acc: 0.6670
# --------------------
# Epoch 85/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9440   Loss: 0.6291   Acc: 0.8339
# Validating [Done!]   Time: 6.2527   Loss: 1.5153   Acc: 0.6614
# --------------------
# Epoch 86/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9857   Loss: 0.6402   Acc: 0.8307
# Validating [Done!]   Time: 6.2422   Loss: 1.4937   Acc: 0.6624
# --------------------
# Epoch 87/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7503   Loss: 0.5879   Acc: 0.8465
# Validating [Done!]   Time: 6.2436   Loss: 1.4809   Acc: 0.6629
# --------------------
# Epoch 88/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9973   Loss: 0.6015   Acc: 0.8417
# Validating [Done!]   Time: 6.2680   Loss: 1.5057   Acc: 0.6593
# --------------------
# Epoch 89/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7887   Loss: 0.6064   Acc: 0.8389
# Validating [Done!]   Time: 6.2450   Loss: 1.5029   Acc: 0.6634
# --------------------
# Epoch 90/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9014   Loss: 0.6061   Acc: 0.8367
# Validating [Done!]   Time: 6.2641   Loss: 1.4948   Acc: 0.6629
#  + Saved checkpoint 'checkpoints/prob1c_2/E90_checkpoint.th'
# --------------------
# Epoch 91/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9123   Loss: 0.5927   Acc: 0.8378
# Validating [Done!]   Time: 6.2850   Loss: 1.4934   Acc: 0.6685
# --------------------
# Epoch 92/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9269   Loss: 0.6264   Acc: 0.8341
# Validating [Done!]   Time: 6.2597   Loss: 1.4903   Acc: 0.6609
# --------------------
# Epoch 93/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.8155   Loss: 0.5604   Acc: 0.8529
# Validating [Done!]   Time: 6.2424   Loss: 1.5351   Acc: 0.6557
# --------------------
# Epoch 94/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7918   Loss: 0.5732   Acc: 0.8492
# Validating [Done!]   Time: 6.2734   Loss: 1.5464   Acc: 0.6609
# --------------------
# Epoch 95/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9688   Loss: 0.5712   Acc: 0.8473
# Validating [Done!]   Time: 6.2752   Loss: 1.5085   Acc: 0.6644
# --------------------
# Epoch 96/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7641   Loss: 0.5815   Acc: 0.8419
# Validating [Done!]   Time: 6.2451   Loss: 1.4925   Acc: 0.6557
# --------------------
# Epoch 97/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9030   Loss: 0.5737   Acc: 0.8455
# Validating [Done!]   Time: 6.2564   Loss: 1.5789   Acc: 0.6532
# --------------------
# Epoch 98/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9299   Loss: 0.5642   Acc: 0.8535
# Validating [Done!]   Time: 6.2500   Loss: 1.5792   Acc: 0.6465
# --------------------
# Epoch 99/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.6385   Loss: 0.5778   Acc: 0.8494
# Validating [Done!]   Time: 6.2544   Loss: 1.5855   Acc: 0.6568
# --------------------
# Epoch 100/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7972   Loss: 0.5938   Acc: 0.8428
# Validating [Done!]   Time: 6.2577   Loss: 1.5661   Acc: 0.6506
#  + Saved checkpoint 'checkpoints/prob1c_2/E100_checkpoint.th'
# --------------------
# Epoch 101/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9579   Loss: 0.5694   Acc: 0.8461
# Validating [Done!]   Time: 6.2600   Loss: 1.5611   Acc: 0.6598
# --------------------
# Epoch 102/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9349   Loss: 0.5849   Acc: 0.8469
# Validating [Done!]   Time: 6.2672   Loss: 1.5443   Acc: 0.6609
# --------------------
# Epoch 103/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7880   Loss: 0.5342   Acc: 0.8577
# Validating [Done!]   Time: 6.2700   Loss: 1.5634   Acc: 0.6562
# --------------------
# Epoch 104/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9231   Loss: 0.5531   Acc: 0.8541
# Validating [Done!]   Time: 6.2886   Loss: 1.5339   Acc: 0.6609
# --------------------
# Epoch 105/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9905   Loss: 0.5312   Acc: 0.8595
# Validating [Done!]   Time: 6.2548   Loss: 1.5457   Acc: 0.6568
# --------------------
# Epoch 106/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9943   Loss: 0.5529   Acc: 0.8559
# Validating [Done!]   Time: 6.2682   Loss: 1.5721   Acc: 0.6588
# --------------------
# Epoch 107/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.6577   Loss: 0.5403   Acc: 0.8574
# Validating [Done!]   Time: 6.2343   Loss: 1.5002   Acc: 0.6619
# --------------------
# Epoch 108/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.6269   Loss: 0.5363   Acc: 0.8574
# Validating [Done!]   Time: 6.3131   Loss: 1.5271   Acc: 0.6609
# --------------------
# Epoch 109/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.8641   Loss: 0.5075   Acc: 0.8635
# Validating [Done!]   Time: 6.2712   Loss: 1.5688   Acc: 0.6511
# --------------------
# Epoch 110/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9720   Loss: 0.5680   Acc: 0.8527
# Validating [Done!]   Time: 6.2626   Loss: 1.5210   Acc: 0.6506
#  + Saved checkpoint 'checkpoints/prob1c_2/E110_checkpoint.th'
# --------------------
# Epoch 111/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9938   Loss: 0.5327   Acc: 0.8612
# Validating [Done!]   Time: 6.2503   Loss: 1.5806   Acc: 0.6506
# --------------------
# Epoch 112/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.6629   Loss: 0.5373   Acc: 0.8560
# Validating [Done!]   Time: 6.2376   Loss: 1.5628   Acc: 0.6588
# --------------------
# Epoch 113/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7544   Loss: 0.5211   Acc: 0.8605
# Validating [Done!]   Time: 6.2745   Loss: 1.5432   Acc: 0.6609
# --------------------
# Epoch 114/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9520   Loss: 0.5233   Acc: 0.8613
# Validating [Done!]   Time: 6.2746   Loss: 1.5408   Acc: 0.6578
# --------------------
# Epoch 115/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.0009   Loss: 0.5283   Acc: 0.8580
# Validating [Done!]   Time: 6.2609   Loss: 1.5772   Acc: 0.6552
# --------------------
# Epoch 116/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9601   Loss: 0.5095   Acc: 0.8671
# Validating [Done!]   Time: 6.2595   Loss: 1.5675   Acc: 0.6603
# --------------------
# Epoch 117/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7096   Loss: 0.5130   Acc: 0.8634
# Validating [Done!]   Time: 6.2252   Loss: 1.6076   Acc: 0.6650
# --------------------
# Epoch 118/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.7723   Loss: 0.5274   Acc: 0.8596
# Validating [Done!]   Time: 6.2523   Loss: 1.6193   Acc: 0.6603
# --------------------
# Epoch 119/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9247   Loss: 0.5189   Acc: 0.8641
# Validating [Done!]   Time: 6.2503   Loss: 1.5845   Acc: 0.6522
# --------------------
# Epoch 120/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.9666   Loss: 0.4968   Acc: 0.8701
# Validating [Done!]   Time: 6.2486   Loss: 1.6143   Acc: 0.6593
#  + Saved checkpoint 'checkpoints/prob1c_2/E120_checkpoint.th'
# --------------------
# Epoch 121/200 (lr = 1.000e-02)
# Training [Done!]   Time: 76.0173   Loss: 0.5042   Acc: 0.8675
# Validating [Done!]   Time: 6.2536   Loss: 1.6015   Acc: 0.6557
# --------------------
# Epoch 122/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.7174   Loss: 0.4788   Acc: 0.8736
# Validating [Done!]   Time: 6.2252   Loss: 1.5849   Acc: 0.6583
# --------------------
# Epoch 123/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.7438   Loss: 0.4989   Acc: 0.8688
# Validating [Done!]   Time: 6.2469   Loss: 1.5811   Acc: 0.6634
# --------------------
# Epoch 124/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8811   Loss: 0.4815   Acc: 0.8705
# Validating [Done!]   Time: 6.2651   Loss: 1.5778   Acc: 0.6588
# --------------------
# Epoch 125/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9768   Loss: 0.4585   Acc: 0.8795
# Validating [Done!]   Time: 6.2522   Loss: 1.5861   Acc: 0.6568
# --------------------
# Epoch 126/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.0030   Loss: 0.4703   Acc: 0.8753
# Validating [Done!]   Time: 6.2695   Loss: 1.5721   Acc: 0.6603
# --------------------
# Epoch 127/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.6656   Loss: 0.4764   Acc: 0.8721
# Validating [Done!]   Time: 6.2245   Loss: 1.5692   Acc: 0.6650
# --------------------
# Epoch 128/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8643   Loss: 0.4609   Acc: 0.8770
# Validating [Done!]   Time: 6.2805   Loss: 1.5754   Acc: 0.6619
# --------------------
# Epoch 129/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.6785   Loss: 0.4408   Acc: 0.8802
# Validating [Done!]   Time: 6.2298   Loss: 1.5797   Acc: 0.6696
# --------------------
# Epoch 130/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8170   Loss: 0.4626   Acc: 0.8753
# Validating [Done!]   Time: 6.2523   Loss: 1.5909   Acc: 0.6573
#  + Saved checkpoint 'checkpoints/prob1c_2/E130_checkpoint.th'
# --------------------
# Epoch 131/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9262   Loss: 0.4690   Acc: 0.8744
# Validating [Done!]   Time: 6.2467   Loss: 1.5720   Acc: 0.6644
# --------------------
# Epoch 132/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9166   Loss: 0.4587   Acc: 0.8778
# Validating [Done!]   Time: 6.2467   Loss: 1.5695   Acc: 0.6670
# --------------------
# Epoch 133/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9043   Loss: 0.4483   Acc: 0.8798
# Validating [Done!]   Time: 6.2526   Loss: 1.5682   Acc: 0.6624
# --------------------
# Epoch 134/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.6375   Loss: 0.4744   Acc: 0.8734
# Validating [Done!]   Time: 6.2753   Loss: 1.5771   Acc: 0.6629
# --------------------
# Epoch 135/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8402   Loss: 0.4521   Acc: 0.8812
# Validating [Done!]   Time: 6.2304   Loss: 1.5547   Acc: 0.6660
# --------------------
# Epoch 136/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9366   Loss: 0.4236   Acc: 0.8899
# Validating [Done!]   Time: 6.2436   Loss: 1.5845   Acc: 0.6609
# --------------------
# Epoch 137/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8763   Loss: 0.4515   Acc: 0.8809
# Validating [Done!]   Time: 6.2611   Loss: 1.5902   Acc: 0.6593
# --------------------
# Epoch 138/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8658   Loss: 0.4572   Acc: 0.8846
# Validating [Done!]   Time: 6.2686   Loss: 1.5824   Acc: 0.6660
# --------------------
# Epoch 139/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.6811   Loss: 0.4513   Acc: 0.8794
# Validating [Done!]   Time: 6.2422   Loss: 1.5624   Acc: 0.6655
# --------------------
# Epoch 140/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.7869   Loss: 0.4490   Acc: 0.8846
# Validating [Done!]   Time: 6.2351   Loss: 1.5946   Acc: 0.6675
#  + Saved checkpoint 'checkpoints/prob1c_2/E140_checkpoint.th'
# --------------------
# Epoch 141/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8912   Loss: 0.4490   Acc: 0.8774
# Validating [Done!]   Time: 6.2395   Loss: 1.5910   Acc: 0.6644
# --------------------
# Epoch 142/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8760   Loss: 0.4560   Acc: 0.8808
# Validating [Done!]   Time: 6.2542   Loss: 1.5666   Acc: 0.6650
# --------------------
# Epoch 143/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.5936   Loss: 0.4595   Acc: 0.8804
# Validating [Done!]   Time: 6.2497   Loss: 1.5793   Acc: 0.6603
# --------------------
# Epoch 144/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8462   Loss: 0.4424   Acc: 0.8831
# Validating [Done!]   Time: 6.2566   Loss: 1.5671   Acc: 0.6716
# --------------------
# Epoch 145/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9384   Loss: 0.4492   Acc: 0.8812
# Validating [Done!]   Time: 6.2316   Loss: 1.5839   Acc: 0.6609
# --------------------
# Epoch 146/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.5607   Loss: 0.4392   Acc: 0.8850
# Validating [Done!]   Time: 6.2200   Loss: 1.5663   Acc: 0.6680
# --------------------
# Epoch 147/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.7683   Loss: 0.4361   Acc: 0.8861
# Validating [Done!]   Time: 6.3086   Loss: 1.5948   Acc: 0.6665
# --------------------
# Epoch 148/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9236   Loss: 0.4577   Acc: 0.8813
# Validating [Done!]   Time: 6.2370   Loss: 1.5828   Acc: 0.6670
# --------------------
# Epoch 149/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.6847   Loss: 0.4566   Acc: 0.8817
# Validating [Done!]   Time: 6.2590   Loss: 1.5915   Acc: 0.6655
# --------------------
# Epoch 150/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8603   Loss: 0.4512   Acc: 0.8809
# Validating [Done!]   Time: 6.2490   Loss: 1.5896   Acc: 0.6701
#  + Saved checkpoint 'checkpoints/prob1c_2/E150_checkpoint.th'
# --------------------
# Epoch 151/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9198   Loss: 0.4431   Acc: 0.8807
# Validating [Done!]   Time: 6.2432   Loss: 1.5762   Acc: 0.6742
# --------------------
# Epoch 152/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.7793   Loss: 0.4442   Acc: 0.8829
# Validating [Done!]   Time: 6.2363   Loss: 1.5659   Acc: 0.6691
# --------------------
# Epoch 153/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9389   Loss: 0.4323   Acc: 0.8850
# Validating [Done!]   Time: 6.2517   Loss: 1.5716   Acc: 0.6680
# --------------------
# Epoch 154/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.7905   Loss: 0.4292   Acc: 0.8871
# Validating [Done!]   Time: 6.2408   Loss: 1.5821   Acc: 0.6639
# --------------------
# Epoch 155/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8394   Loss: 0.4346   Acc: 0.8849
# Validating [Done!]   Time: 6.2443   Loss: 1.5777   Acc: 0.6711
# --------------------
# Epoch 156/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.7296   Loss: 0.4473   Acc: 0.8833
# Validating [Done!]   Time: 6.2415   Loss: 1.5543   Acc: 0.6752
# --------------------
# Epoch 157/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9153   Loss: 0.4374   Acc: 0.8869
# Validating [Done!]   Time: 6.2450   Loss: 1.5547   Acc: 0.6685
# --------------------
# Epoch 158/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9761   Loss: 0.4192   Acc: 0.8893
# Validating [Done!]   Time: 6.2267   Loss: 1.5684   Acc: 0.6716
# --------------------
# Epoch 159/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.6728   Loss: 0.4224   Acc: 0.8893
# Validating [Done!]   Time: 6.2199   Loss: 1.5708   Acc: 0.6742
# --------------------
# Epoch 160/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.7944   Loss: 0.4157   Acc: 0.8900
# Validating [Done!]   Time: 6.2555   Loss: 1.5694   Acc: 0.6691
#  + Saved checkpoint 'checkpoints/prob1c_2/E160_checkpoint.th'
# --------------------
# Epoch 161/200 (lr = 1.000e-03)
# Training [Done!]   Time: 76.0036   Loss: 0.4379   Acc: 0.8860
# Validating [Done!]   Time: 6.2514   Loss: 1.5649   Acc: 0.6716
# --------------------
# Epoch 162/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.7410   Loss: 0.4363   Acc: 0.8850
# Validating [Done!]   Time: 6.2310   Loss: 1.5663   Acc: 0.6747
# --------------------
# Epoch 163/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8787   Loss: 0.4514   Acc: 0.8820
# Validating [Done!]   Time: 6.2523   Loss: 1.5707   Acc: 0.6711
# --------------------
# Epoch 164/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.5269   Loss: 0.4367   Acc: 0.8833
# Validating [Done!]   Time: 6.2342   Loss: 1.5483   Acc: 0.6762
# --------------------
# Epoch 165/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8140   Loss: 0.4289   Acc: 0.8868
# Validating [Done!]   Time: 6.2319   Loss: 1.5629   Acc: 0.6732
# --------------------
# Epoch 166/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.6123   Loss: 0.4495   Acc: 0.8829
# Validating [Done!]   Time: 6.2422   Loss: 1.5707   Acc: 0.6742
# --------------------
# Epoch 167/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9329   Loss: 0.4413   Acc: 0.8854
# Validating [Done!]   Time: 6.2592   Loss: 1.5813   Acc: 0.6732
# --------------------
# Epoch 168/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.6684   Loss: 0.4329   Acc: 0.8854
# Validating [Done!]   Time: 6.2299   Loss: 1.5837   Acc: 0.6691
# --------------------
# Epoch 169/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8301   Loss: 0.4457   Acc: 0.8831
# Validating [Done!]   Time: 6.2609   Loss: 1.5751   Acc: 0.6655
# --------------------
# Epoch 170/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9661   Loss: 0.4160   Acc: 0.8873
# Validating [Done!]   Time: 6.2512   Loss: 1.5884   Acc: 0.6721
#  + Saved checkpoint 'checkpoints/prob1c_2/E170_checkpoint.th'
# --------------------
# Epoch 171/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9558   Loss: 0.4306   Acc: 0.8841
# Validating [Done!]   Time: 6.2556   Loss: 1.5722   Acc: 0.6721
# --------------------
# Epoch 172/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.7691   Loss: 0.4315   Acc: 0.8860
# Validating [Done!]   Time: 6.2308   Loss: 1.5724   Acc: 0.6737
# --------------------
# Epoch 173/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.7612   Loss: 0.4279   Acc: 0.8862
# Validating [Done!]   Time: 6.2560   Loss: 1.5660   Acc: 0.6773
# --------------------
# Epoch 174/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9312   Loss: 0.4138   Acc: 0.8889
# Validating [Done!]   Time: 6.2351   Loss: 1.5660   Acc: 0.6706
# --------------------
# Epoch 175/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.7000   Loss: 0.4176   Acc: 0.8874
# Validating [Done!]   Time: 6.2256   Loss: 1.5568   Acc: 0.6680
# --------------------
# Epoch 176/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.6489   Loss: 0.4235   Acc: 0.8899
# Validating [Done!]   Time: 6.2332   Loss: 1.5625   Acc: 0.6680
# --------------------
# Epoch 177/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8737   Loss: 0.4264   Acc: 0.8852
# Validating [Done!]   Time: 6.2513   Loss: 1.5624   Acc: 0.6721
# --------------------
# Epoch 178/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8328   Loss: 0.4385   Acc: 0.8831
# Validating [Done!]   Time: 6.2266   Loss: 1.5634   Acc: 0.6747
# --------------------
# Epoch 179/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.9183   Loss: 0.4285   Acc: 0.8862
# Validating [Done!]   Time: 6.2659   Loss: 1.5789   Acc: 0.6675
# --------------------
# Epoch 180/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.8273   Loss: 0.4281   Acc: 0.8807
# Validating [Done!]   Time: 6.2268   Loss: 1.5834   Acc: 0.6660
#  + Saved checkpoint 'checkpoints/prob1c_2/E180_checkpoint.th'
# --------------------
# Epoch 181/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.5998   Loss: 0.4174   Acc: 0.8899
# Validating [Done!]   Time: 6.2476   Loss: 1.5698   Acc: 0.6680
# --------------------
# Epoch 182/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.8663   Loss: 0.4285   Acc: 0.8885
# Validating [Done!]   Time: 6.2276   Loss: 1.5831   Acc: 0.6701
# --------------------
# Epoch 183/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.6694   Loss: 0.4115   Acc: 0.8916
# Validating [Done!]   Time: 6.2148   Loss: 1.5625   Acc: 0.6696
# --------------------
# Epoch 184/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.7098   Loss: 0.4027   Acc: 0.8962
# Validating [Done!]   Time: 6.2364   Loss: 1.5633   Acc: 0.6711
# --------------------
# Epoch 185/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.9302   Loss: 0.4265   Acc: 0.8874
# Validating [Done!]   Time: 6.2620   Loss: 1.5662   Acc: 0.6742
# --------------------
# Epoch 186/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.8578   Loss: 0.4485   Acc: 0.8815
# Validating [Done!]   Time: 6.2423   Loss: 1.5882   Acc: 0.6660
# --------------------
# Epoch 187/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.9535   Loss: 0.4457   Acc: 0.8831
# Validating [Done!]   Time: 6.2568   Loss: 1.5791   Acc: 0.6670
# --------------------
# Epoch 188/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.6965   Loss: 0.4190   Acc: 0.8915
# Validating [Done!]   Time: 6.2474   Loss: 1.5793   Acc: 0.6675
# --------------------
# Epoch 189/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.9169   Loss: 0.4310   Acc: 0.8811
# Validating [Done!]   Time: 6.2770   Loss: 1.6085   Acc: 0.6655
# --------------------
# Epoch 190/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.9465   Loss: 0.4048   Acc: 0.8899
# Validating [Done!]   Time: 6.2470   Loss: 1.5606   Acc: 0.6716
#  + Saved checkpoint 'checkpoints/prob1c_2/E190_checkpoint.th'
# --------------------
# Epoch 191/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.8919   Loss: 0.4270   Acc: 0.8861
# Validating [Done!]   Time: 6.2515   Loss: 1.5474   Acc: 0.6762
# --------------------
# Epoch 192/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.8001   Loss: 0.4100   Acc: 0.8936
# Validating [Done!]   Time: 6.3079   Loss: 1.5856   Acc: 0.6650
# --------------------
# Epoch 193/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.8726   Loss: 0.4139   Acc: 0.8910
# Validating [Done!]   Time: 6.2522   Loss: 1.5621   Acc: 0.6721
# --------------------
# Epoch 194/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.8229   Loss: 0.4039   Acc: 0.8936
# Validating [Done!]   Time: 6.2518   Loss: 1.5799   Acc: 0.6670
# --------------------
# Epoch 195/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.8234   Loss: 0.4075   Acc: 0.8923
# Validating [Done!]   Time: 6.2525   Loss: 1.5622   Acc: 0.6665
# --------------------
# Epoch 196/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.9562   Loss: 0.4136   Acc: 0.8915
# Validating [Done!]   Time: 6.2595   Loss: 1.5574   Acc: 0.6747
# --------------------
# Epoch 197/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.9456   Loss: 0.4299   Acc: 0.8877
# Validating [Done!]   Time: 6.2586   Loss: 1.5677   Acc: 0.6752
# --------------------
# Epoch 198/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.7062   Loss: 0.4282   Acc: 0.8856
# Validating [Done!]   Time: 6.3082   Loss: 1.5665   Acc: 0.6701
# --------------------
# Epoch 199/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.8850   Loss: 0.4049   Acc: 0.8931
# Validating [Done!]   Time: 6.2508   Loss: 1.5651   Acc: 0.6711
# --------------------
# Epoch 200/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.8688   Loss: 0.4234   Acc: 0.8856
# Validating [Done!]   Time: 6.2689   Loss: 1.5631   Acc: 0.6706
# --------------------
#  + Saved checkpoint 'checkpoints/prob1c_2/final_model.th'
# Training complete in 273m 19s
# Best val Acc: 0.677254

# %% [markdown]
# _Note: the following snippet was copied from the actual console output that included all 200 epochs. Here the output is shortened for brevity, but still illustrates the learning rate decay as well as shows the first and last epoch._
# ```
# Training model...
# ====================
# Epoch 1/200 (lr = 1.000e-01)
# Training [Done!]   Time: 74.2095   Loss: 4.7203   Acc: 0.0161
# Validating [Done!]   Time: 6.1948   Loss: 4.4782   Acc: 0.0179
# --------------------
# ...
# --------------------
# Epoch 62/200 (lr = 1.000e-02)
# Training [Done!]   Time: 75.8188   Loss: 0.9828   Acc: 0.7429
# Validating [Done!]   Time: 6.2297   Loss: 1.4431   Acc: 0.6429
# --------------------
# ...
# --------------------
# Epoch 122/200 (lr = 1.000e-03)
# Training [Done!]   Time: 75.7174   Loss: 0.4788   Acc: 0.8736
# Validating [Done!]   Time: 6.2252   Loss: 1.5849   Acc: 0.6583
# --------------------
# ...
# --------------------
# Epoch 182/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.8663   Loss: 0.4285   Acc: 0.8885
# Validating [Done!]   Time: 6.2276   Loss: 1.5831   Acc: 0.6701
# --------------------
# ...
# --------------------
# Epoch 200/200 (lr = 1.000e-04)
# Training [Done!]   Time: 75.8688   Loss: 0.4234   Acc: 0.8856
# Validating [Done!]   Time: 6.2689   Loss: 1.5631   Acc: 0.6706
# --------------------
#  + Saved checkpoint 'checkpoints/prob1c_2/final_model.th'
# Training complete in 273m 19s
# Best val Acc: 0.677254
# ```

# %%
prob_names = ['prob1b','prob1c_1','prob1c_2']
history = {'prob1b':{},'prob1c_1':{},'prob1c_2':{}}
for prob_name in history.keys():
    # load the stored json data into dictionary if it doesn't exist
    hist_file = 'checkpoints/{}/final_history.json'.format(prob_name)
    if os.path.isfile(hist_file):
        with open(hist_file) as json_file:
            history[prob_name] = json.load(json_file)
            print('Loaded data from JSON file. (file:{})\n'.format(hist_file))
    else:
        sys.exit('File \'{}\' does not exist.'.format(hist_file))

# display the resuls
plt_1b = history['prob1b']['val']
plt_1c1 = history['prob1c_1']['val']
plt_1c2 = history['prob1c_2']['val']

# best acc text
best_1b = 'Best acc: {:0.3f}'.format(plt_1b['best_acc'])
best_1c1 = 'Best acc: {:0.3f}'.format(plt_1c1['best_acc'] )
best_1c2 = 'Best acc: {:0.3f}'.format(plt_1c2['best_acc'] )

# define figure
title = 'Q1.1c - Finetuning Resnet50 for \'{}\' Dataset'.format(data_name)
fig = plt.figure(figsize=(12,5))
fig.suptitle(title, fontsize=16)
##
ax1 = fig.add_subplot(1, 3, 1)
ax1.set_title('1b - Validation (lr: 0.001)')
ax1.set_ylabel('Accuracy')
ax1.plot(plt_1b['epoch'], plt_1b['acc'], color='indigo')
ax1.text(0.05, 0.95, best_1b, transform=ax1.transAxes, fontsize=10,
        verticalalignment='top')
##
ax2 = fig.add_subplot(1, 3, 2,sharey = ax1)
ax2.set_title('1c_1 - Validation (lr: 0.01)')
ax2.set_xlabel('Epoch')
ax2.plot(plt_1c1['epoch'], plt_1c1['acc'], color='teal')
ax2.text(0.05, 0.95, best_1c1, transform=ax2.transAxes, fontsize=10,
        verticalalignment='top')
##
ax3 = fig.add_subplot(1, 3, 3,sharey = ax1)
ax3.set_title('1c_2 - Validation (lr: 0.1)')
ax3.plot(plt_1c2['epoch'], plt_1c2['acc'], color='maroon')
ax3.text(0.05, 0.95, best_1c2, transform=ax3.transAxes, fontsize=10,
        verticalalignment='top')

##
# configure ticks/labels/layout
plt.tight_layout(pad=2.0)
plt.show()
# Out:
# Loaded data from JSON file. (file:checkpoints/prob1b/final_history.json)
#
# Loaded data from JSON file. (file:checkpoints/prob1c_1/final_history.json)
#
# Loaded data from JSON file. (file:checkpoints/prob1c_2/final_history.json)

# %% [markdown]
# ### 2(a)

# %% [markdown]
# ### 2(b)

# %% [markdown]
# # Problem 2 - Weakly and Semi-Supervised Learning for Image Classification (20) {-}

# %% [markdown]
# # Problem 3 - PALEO, FLOPs, Platform Percent of Peak (PPP) (20) {-}

# %% [markdown]
# # Problem 4 - Optimus, Learning and Resource models, Performance-cost tradeoffs (30) {-}

# %% [markdown]
# ### 4.1
# __Generate the data for predictive model calibration. Train Resnet models with different number of layers (18, 20, 32, 44, 56) each with 3 different GPU types (K80, P100, V100). Use the CIFAR10 dataset with a batch size of 128 and run the training for 350 epochs.__
#
# __Additional consideratons:__  _According to Piazza (@303) we are not concerned with the validation accuracy, so we will not perform any pre-processing (e.g., resize w/ random crop) or data augmentation. We chose to use PyTorch models with an SGD optimizer (per the reference paper) and a initial learning rate of $0.1$. Finally, our learning rate decay schema was chosen to be a simple step of $100$ epochs at a rate of $0.1$  model_
#
# The team members and respective Resnet layer assignments are as follows:
# * Nicholas Christman, 18 layers (native PyTorch [Resnet18](https://pytorch.org/docs/stable/torchvision/models.html#id10))
# * Zach Lawless, 20 layers (akamster PyTorch [Resnet20](https://github.com/akamaster/pytorch_resnet_cifar10/blob/master/resnet.py))
# * Wang Yao, 32 layers (akamaster PyTorch [Resnet32](https://github.com/akamaster/pytorch_resnet_cifar10/blob/master/resnet.py))
# * Roberto Ponce, 44 layers (akamaster PyTorch [Resnet44](https://github.com/akamaster/pytorch_resnet_cifar10/blob/master/resnet.py))
# * Shawn Pachgade 56 layers (akamaster PyTorch [Resnet56](https://github.com/akamaster/pytorch_resnet_cifar10/blob/master/resnet.py))
#
# The following framework was shared amongst team members to ensure results were achieved using the exact same methodology.

# %%
def train_model(model, resnet_layers, hardware, dataloaders, criterion, 
                optimizer, scheduler, num_epochs=350,save_epochs=10, 
                save_dir='', status_epochs=1, train_acc=0):
    since = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    metrics = []
    training_step = 0
    acc_reached = False
    for epoch in range(num_epochs):
        if (epoch) % status_epochs == 0 or epoch == num_epochs-1:
            print()
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()
            epoch_phase_start_time = time.time()
            running_loss = 0.0
            running_corrects = 0
            for inputs, labels in dataloaders[phase]:
                step_start_time = time.time()
                inputs = inputs.to(device)
                labels = labels.to(device)
                optimizer.zero_grad()
                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                        metrics.append({
                            'resnet_layers': resnet_layers,
                            'hardware': hardware,
                            'epoch': epoch,
                            'training_step': training_step,
                            'training_step_loss': loss.item(),
                            'training_step_time': time.time() - step_start_time
                        })
                        training_step += 1
                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            epoch_phase_end_time = time.time()
            
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc.item()
                best_model_wts = copy.deepcopy(model.state_dict())
            
            # check if training accuracy has met target, if so exit
            if (train_acc > 0) and (epoch_acc.item() >= train_acc) and phase == 'train':
                acc_reached = True
                print()
                print(f'Epoch {epoch}/{num_epochs - 1}')
                print('-' * 10)
                
            if (epoch) % status_epochs == 0 or epoch == num_epochs-1 or acc_reached:
                print(f'{phase} Loss: {round(epoch_loss, 4)} Acc: {round(epoch_acc.item(), 4)}')
            else:
                prog = '-' * int(((epoch) % status_epochs))
                print('\r{}|{}'.format(prog,epoch),end='')
                
             # check if training accuracy has met target, if so exit
            if (train_acc > 0) and (epoch_acc.item() >= train_acc) and phase == 'train':
                acc_reached = True

        ####### save checkpoint after epoch
        if (epoch > 0 and epoch != num_epochs-1) and \
            ((epoch+1) % save_epochs == 0 and os.path.isdir(save_dir)):
            checkpoint=os.path.join(save_dir, 
                                'checkpoint_model.th'.format(epoch+1))
            torch.save({
                'epoch': epoch + 1,
                'state_dict': model.state_dict(),
                'best_acc': best_acc,
            }, checkpoint)
            # dump the data for later
            json_file = os.path.join(save_dir,
                                     'checkpoint_metrics.json'.format(epoch+1))
            with open(json_file, 'w') as fp:
                json.dump(metrics, fp)
        #######
        
        # if the target accuracy was reached during this epoch, it is time to exit
        if acc_reached: 
            break;
       
        
    
    ####### save checkpoint
    if os.path.isdir(save_dir):
        checkpoint= os.path.join(save_dir, 'final_{}_model.th'.format(hardware))
        # save the model
        torch.save({
            'state_dict': model.state_dict(),
            'best_acc': best_acc,
        }, checkpoint)
        # dump the data for later
        metric_path = os.path.join(save_dir,'final_{}_metrics.json'.format(hardware))
        with open(metric_path, 'w') as fp:
            json.dump(metrics, fp)
    #######
    
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60}m {time_elapsed % 60}s')
    print(f'Best val Acc: {round(best_acc, 4)}')
    # load best model weights
    model.load_state_dict(best_model_wts)
    # set up return structure
    return_df = pd.DataFrame(data=metrics)
    return model, return_df

# helper function to get GPU name
# tested on Tesla V100, P100, K80
def get_gpu_name(gpu_class='Tesla',verbose=0):
    import subprocess
    import re
    nvidia_smi = subprocess.check_output(['nvidia-smi']).decode('utf8')
    match = re.search(r'{} (\S+)'.format(gpu_class), nvidia_smi)
    gpu = match.group(1).split('-')[0]
    if verbose > 0:
        print('GPU: {}'.format(gpu))
    if verbose == 2:
        print(nvidia_smi)
    return str(gpu).upper()

# %%
BATCHSIZE = 128
DATA_DIR = 'data/cifar10'
# Data augmentation and normalization for training
data_transforms = {
    'train': transforms.Compose([
#         transforms.Pad(4),
#         transforms.RandomHorizontalFlip(),
#         transforms.RandomCrop(32),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ]),
}
train_set = torchvision.datasets.CIFAR10(root=DATA_DIR, train=True,
                                        download=False, transform=data_transforms['train'])
val_set = torchvision.datasets.CIFAR10(root=DATA_DIR, train=False,
                                       download=False, transform=data_transforms['val'])
image_datasets = {'train': train_set, 'val': val_set}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=BATCHSIZE,
                                              shuffle=True, num_workers=4)
               for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Dataset sizes: {dataset_sizes}")
print(f"Class names: {class_names}")
# Out:
# Dataset sizes: {'train': 50000, 'val': 10000}
# Class names: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# #### The following training was executed on a K80 GPU

# %%
prob_name = 'prob4_1'
save_epochs = 10
history = {}

# for checkpoints (save/load dir)
start_epoch = 0
save_dir = os.path.join('checkpoints',prob_name)
if not os.path.isdir(save_dir): os.mkdir(save_dir) # create save_dir
# model_ft, history = load_checkpoint(model, save_dir, start_epoch) # uncomment to load model

# Fetch PyTorch model
model = models.resnet18()
# Set up criterion
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
# Decay LR by a factor of 0.1 every 100 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.1)
# Send model to device
model = model.to(device)
# Train
num_epochs = 350
resnet_layers = 18
hardware = get_gpu_name(verbose=1) #'K80'
model, results_df = train_model(model, resnet_layers, hardware, dataloaders,
                                criterion, optimizer, exp_lr_scheduler, num_epochs,
                                save_epochs=save_epochs, save_dir=save_dir,
                                status_epochs=np.ceil(num_epochs/10))

# save the data for others to use
results_file = 'resnet18_{}.csv'.format(hardware)
df_path = os.path.join(save_dir,results_file)
results_df.to_csv(df_path,columns=results_df.columns)

# %% [markdown]
# _Note: this is the output from the actual training_
# ```
# GPU: K80
#
# Epoch 0/349
# ----------
# train Loss: 2.1904 Acc: 0.3207
# val Loss: 1.5098 Acc: 0.4541
# ----------------------------------|34
# Epoch 35/349
# ----------
# train Loss: 0.0274 Acc: 0.9904
# val Loss: 1.6949 Acc: 0.7327
# ----------------------------------|69
# Epoch 70/349
# ----------
# train Loss: 0.0063 Acc: 0.9979
# val Loss: 2.1796 Acc: 0.7343
# ----------------------------------|104
# Epoch 105/349
# ----------
# train Loss: 0.0002 Acc: 1.0
# val Loss: 2.443 Acc: 0.7436
# ----------------------------------|139
# Epoch 140/349
# ----------
# train Loss: 0.0001 Acc: 1.0
# val Loss: 2.5812 Acc: 0.7472
# ----------------------------------|174
# Epoch 175/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.633 Acc: 0.7462
# ----------------------------------|209
# Epoch 210/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6226 Acc: 0.7453
# ----------------------------------|244
# Epoch 245/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6654 Acc: 0.746
# ----------------------------------|279
# Epoch 280/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6644 Acc: 0.7462
# ----------------------------------|314
# Epoch 315/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6533 Acc: 0.7468
# ---------------------------------|348
# Epoch 349/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6471 Acc: 0.746
# Training complete in 739.0m 29.309322595596313s
# Best val Acc: 0.7481
# ```

# %% [markdown]
# #### The following training was executed on a V100 GPU

# %%
prob_name = 'prob4_1'
save_epochs = 10
history = {}

# for checkpoints (save/load dir)
start_epoch = 0
save_dir = os.path.join('checkpoints',prob_name)
if not os.path.isdir(save_dir): os.mkdir(save_dir) # create save_dir
# model_ft, history = load_checkpoint(model, save_dir, start_epoch) # uncomment to load model

# Fetch PyTorch model
model = models.resnet18()
# Set up criterion
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
# Decay LR by a factor of 0.1 every 100 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.1)
# Send model to device
model = model.to(device)
# Train
num_epochs = 350
resnet_layers = 18
hardware = get_gpu_name(verbose=1) #'V100'
model, results_df = train_model(model, resnet_layers, hardware, dataloaders,
                                criterion, optimizer, exp_lr_scheduler, num_epochs,
                                save_epochs=save_epochs, save_dir=save_dir,
                                status_epochs=np.ceil(num_epochs/10))

# save the data for others to use
results_file = 'resnet18_{}.csv'.format(hardware)
df_path = os.path.join(save_dir,results_file)
results_df.to_csv(df_path,columns=results_df.columns)
# Out:
# GPU: V100
#
# Epoch 0/349
# ----------
# train Loss: 2.0319 Acc: 0.3468
# val Loss: 1.4961 Acc: 0.4513
# ----------------------------------|34
# Epoch 35/349
# ----------
# train Loss: 0.027 Acc: 0.9907
# val Loss: 1.836 Acc: 0.7402
# ----------------------------------|69
# Epoch 70/349
# ----------
# train Loss: 0.0046 Acc: 0.9986
# val Loss: 2.3402 Acc: 0.7436
# ----------------------------------|104
# Epoch 105/349
# ----------
# train Loss: 0.0005 Acc: 0.9999
# val Loss: 2.3679 Acc: 0.7475
# ----------------------------------|139
# Epoch 140/349
# ----------
# train Loss: 0.0001 Acc: 1.0
# val Loss: 2.4785 Acc: 0.7512
# ----------------------------------|174
# Epoch 175/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6757 Acc: 0.7486
# ----------------------------------|209
# Epoch 210/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6244 Acc: 0.7511
# ----------------------------------|244
# Epoch 245/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6587 Acc: 0.7518
# ----------------------------------|279
# Epoch 280/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.756 Acc: 0.7506
# ----------------------------------|314
# Epoch 315/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6365 Acc: 0.7524
# ---------------------------------|348
# Epoch 349/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6803 Acc: 0.7489
# Training complete in 52.0m 11.517183780670166s
# Best val Acc: 0.7526

# %% [markdown]
# _Note: this is the output from the actual training_
#
# ```
# GPU: V100
#
# Epoch 0/349
# ----------
# train Loss: 2.0319 Acc: 0.3468
# val Loss: 1.4961 Acc: 0.4513
# ----------------------------------|34
# Epoch 35/349
# ----------
# train Loss: 0.027 Acc: 0.9907
# val Loss: 1.836 Acc: 0.7402
# ----------------------------------|69
# Epoch 70/349
# ----------
# train Loss: 0.0046 Acc: 0.9986
# val Loss: 2.3402 Acc: 0.7436
# ----------------------------------|104
# Epoch 105/349
# ----------
# train Loss: 0.0005 Acc: 0.9999
# val Loss: 2.3679 Acc: 0.7475
# ----------------------------------|139
# Epoch 140/349
# ----------
# train Loss: 0.0001 Acc: 1.0
# val Loss: 2.4785 Acc: 0.7512
# ----------------------------------|174
# Epoch 175/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6757 Acc: 0.7486
# ----------------------------------|209
# Epoch 210/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6244 Acc: 0.7511
# ----------------------------------|244
# Epoch 245/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6587 Acc: 0.7518
# ----------------------------------|279
# Epoch 280/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.756 Acc: 0.7506
# ----------------------------------|314
# Epoch 315/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6365 Acc: 0.7524
# ---------------------------------|348
# Epoch 349/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6803 Acc: 0.7489
# Training complete in 52.0m 11.517183780670166s
# Best val Acc: 0.7526
# ```

# %% [markdown]
# #### The following training was executed on a P100 GPU

# %%
prob_name = 'prob4_1'
save_epochs = 10
history = {}

# for checkpoints (save/load dir)
start_epoch = 0
save_dir = os.path.join('checkpoints',prob_name)
if not os.path.isdir(save_dir): os.mkdir(save_dir) # create save_dir
# model_ft, history = load_checkpoint(model, save_dir, start_epoch) # uncomment to load model

# Fetch PyTorch model
model = models.resnet18()
# Set up criterion
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
# Decay LR by a factor of 0.1 every 100 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.1)
# Send model to device
model = model.to(device)
# Train
num_epochs = 350
resnet_layers = 18
hardware = get_gpu_name(verbose=1) #'P100'
model, results_df = train_model(model, resnet_layers, hardware, dataloaders,
                                criterion, optimizer, exp_lr_scheduler, num_epochs,
                                save_epochs=save_epochs, save_dir=save_dir,
                                status_epochs=np.ceil(num_epochs/10))

# save the data for others to use
results_file = 'resnet18_{}.csv'.format(hardware)
df_path = os.path.join(save_dir,results_file)
results_df.to_csv(df_path,columns=results_df.columns)
# Out:
# GPU: P100
#
# Epoch 0/349
# ----------
# train Loss: 2.0814 Acc: 0.344
# val Loss: 1.7376 Acc: 0.4525
# ----------------------------------|34
# Epoch 35/349
# ----------
# train Loss: 0.0188 Acc: 0.9937
# val Loss: 2.0934 Acc: 0.7342
# ----------------------------------|69
# Epoch 70/349
# ----------
# train Loss: 0.0056 Acc: 0.9984
# val Loss: 2.243 Acc: 0.734
# ----------------------------------|104
# Epoch 105/349
# ----------
# train Loss: 0.0003 Acc: 0.9999
# val Loss: 2.4724 Acc: 0.7418
# ----------------------------------|139
# Epoch 140/349
# ----------
# train Loss: 0.0001 Acc: 1.0
# val Loss: 2.5989 Acc: 0.7427
# ----------------------------------|174
# Epoch 175/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6586 Acc: 0.7413
# ----------------------------------|209
# Epoch 210/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6552 Acc: 0.7422
# ----------------------------------|244
# Epoch 245/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6059 Acc: 0.7423
# ----------------------------------|279
# Epoch 280/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6745 Acc: 0.7446
# ----------------------------------|314
# Epoch 315/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6252 Acc: 0.7441
# ---------------------------------|348
# Epoch 349/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6804 Acc: 0.7446
# Training complete in 72.0m 28.087385416030884s
# Best val Acc: 0.7457

# %% [markdown]
# _Note: this is the output from the actual training_
# ```
# GPU: P100
#
# Epoch 0/349
# ----------
# train Loss: 2.0814 Acc: 0.344
# val Loss: 1.7376 Acc: 0.4525
# ----------------------------------|34
# Epoch 35/349
# ----------
# train Loss: 0.0188 Acc: 0.9937
# val Loss: 2.0934 Acc: 0.7342
# ----------------------------------|69
# Epoch 70/349
# ----------
# train Loss: 0.0056 Acc: 0.9984
# val Loss: 2.243 Acc: 0.734
# ----------------------------------|104
# Epoch 105/349
# ----------
# train Loss: 0.0003 Acc: 0.9999
# val Loss: 2.4724 Acc: 0.7418
# ----------------------------------|139
# Epoch 140/349
# ----------
# train Loss: 0.0001 Acc: 1.0
# val Loss: 2.5989 Acc: 0.7427
# ----------------------------------|174
# Epoch 175/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6586 Acc: 0.7413
# ----------------------------------|209
# Epoch 210/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6552 Acc: 0.7422
# ----------------------------------|244
# Epoch 245/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6059 Acc: 0.7423
# ----------------------------------|279
# Epoch 280/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6745 Acc: 0.7446
# ----------------------------------|314
# Epoch 315/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6252 Acc: 0.7441
# ---------------------------------|348
# Epoch 349/349
# ----------
# train Loss: 0.0 Acc: 1.0
# val Loss: 2.6804 Acc: 0.7446
# Training complete in 72.0m 28.087385416030884s
# Best val Acc: 0.7457
# ```

# %%
# os.system('sudo shutdown now')

# %% [markdown]
# #### Now we will estimate the values of ($\beta_{0},\beta_{1},\beta_{2}$):

# %%
# load all of the data into a Pandas dataframe the data
load_dir = 'data/prob4_results'

dfs = []
for file in os.path.listdir(load_dir):
    if file.endswith('.csv'):
        df = pd.read_csv(file, index_col=None, header=0)
        dfs.append(df)

df = pd.concat(dfs, axis=0, ignore_index=True)

# %% [markdown]
# ### 4.2
# __From the regresssion model in 4.1, predict the training loss curve for Resnet-50. To verify how good is this prediction, train Resnet-50 on a K80, P100, and V100 for target accuracy of 92% and compare the predicted loss curve with the real measurements.__

# %%
# regression goes here
from sklearn import linear_model

# %% [markdown]
# #### Now we will validate our estimate obtained from the regression model by training a Resnet50 model on the CIFAR10 dataset using the exact same framework and hyperparameters before. This will be completed on the 3 GPUS (K80, P100, & V100)

# %%
# NOTE: the same framework from 4.1 is used, so the functions, dataset, dataloaders, etc., need to be initialized above.
prob_name = 'prob4_2'
save_epochs = 10
history = {}

# for checkpoints (save/load dir)
start_epoch = 0
save_dir = os.path.join('checkpoints',prob_name)
if not os.path.isdir(save_dir): os.mkdir(save_dir) # create save_dir
# model_ft, history = load_checkpoint(model, save_dir, start_epoch) # uncomment to load model

# Fetch PyTorch model
model = models.resnet50()
# Set up criterion
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
# Decay LR by a factor of 0.1 every 100 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.1)
# Send model to device
model = model.to(device)
# Train
num_epochs = 350
resnet_layers = 50
target_acc = 0.92
hardware = get_gpu_name(verbose=1) #'V100'
model, results_df = train_model(model, resnet_layers, hardware, dataloaders,
                                criterion, optimizer, exp_lr_scheduler, num_epochs,
                                save_epochs=save_epochs, save_dir=save_dir,
                                status_epochs=np.ceil(num_epochs/10),train_acc=target_acc)


# save the data for others to use
results_file = 'resnet50_{}.csv'.format(hardware)
df_path = os.path.join(save_dir,results_file)
results_df.to_csv(df_path,columns=results_df.columns)
# Out:
# GPU: V100
#
# Epoch 0/349
# ----------
# train Loss: 4.6 Acc: 0.1279
# val Loss: 2.2781 Acc: 0.1417
# ----------------------------------|34
# Epoch 35/349
# ----------
#
# Epoch 35/349
# ----------
# train Loss: 0.2056 Acc: 0.9263
# val Loss: 5.6081 Acc: 0.5909
# Training complete in 11.0m 45.89620280265808s
# Best val Acc: 0.5983

# %% [markdown]
# _Note: this is the output from the actual training_
# ```
# GPU: V100
#
# Epoch 0/349
# ----------
# train Loss: 4.6 Acc: 0.1279
# val Loss: 2.2781 Acc: 0.1417
# ----------------------------------|34
# Epoch 35/349
# ----------
# train Loss: 0.2056 Acc: 0.9263
# val Loss: 5.6081 Acc: 0.5909
# Training complete in 11.0m 45.89620280265808s
# Best val Acc: 0.5983
# ```

# %%
# NOTE: the same framework from 4.1 is used, so the functions, dataset, dataloaders, etc., need to be initialized above.
prob_name = 'prob4_2'
save_epochs = 10
history = {}

# for checkpoints (save/load dir)
start_epoch = 0
save_dir = os.path.join('checkpoints',prob_name)
if not os.path.isdir(save_dir): os.mkdir(save_dir) # create save_dir
# model_ft, history = load_checkpoint(model, save_dir, start_epoch) # uncomment to load model

# Fetch PyTorch model
model = models.resnet50()
# Set up criterion
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
# Decay LR by a factor of 0.1 every 100 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.1)
# Send model to device
model = model.to(device)
# Train
num_epochs = 350
resnet_layers = 50
target_acc = 0.92
hardware = get_gpu_name(verbose=1) #'P100'
model, results_df = train_model(model, resnet_layers, hardware, dataloaders,
                                criterion, optimizer, exp_lr_scheduler, num_epochs,
                                save_epochs=save_epochs, save_dir=save_dir,
                                status_epochs=np.ceil(num_epochs/10),train_acc=target_acc)


# save the data for others to use
results_file = 'resnet50_{}.csv'.format(hardware)
df_path = os.path.join(save_dir,results_file)
results_df.to_csv(df_path,columns=results_df.columns)
# Out:
# GPU: P100
#
# Epoch 0/349
# ----------
# train Loss: 4.6623 Acc: 0.1674
# val Loss: 2.4195 Acc: 0.2177
# ---------------------------|27
# Epoch 28/349
# ----------
# train Loss: 0.2172 Acc: 0.9227
# val Loss: 2.4185 Acc: 0.6269
# Training complete in 14.0m 18.385379791259766s
# Best val Acc: 0.6269

# %% [markdown]
# _Note: this is the output from the actual training_
# ```
# GPU: P100
#
# Epoch 0/349
# ----------
# train Loss: 4.6623 Acc: 0.1674
# val Loss: 2.4195 Acc: 0.2177
# ---------------------------|27
# Epoch 28/349
# ----------
# train Loss: 0.2172 Acc: 0.9227
# val Loss: 2.4185 Acc: 0.6269
# Training complete in 14.0m 18.385379791259766s
# Best val Acc: 0.6269
# ```

# %%
# NOTE: the same framework from 4.1 is used, so the functions, dataset, dataloaders, etc., need to be initialized above.
prob_name = 'prob4_2'
save_epochs = 10
history = {}

# for checkpoints (save/load dir)
start_epoch = 0
save_dir = os.path.join('checkpoints',prob_name)
if not os.path.isdir(save_dir): os.mkdir(save_dir) # create save_dir
# model_ft, history = load_checkpoint(model, save_dir, start_epoch) # uncomment to load model

# Fetch PyTorch model
model = models.resnet50()
# Set up criterion
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
# Decay LR by a factor of 0.1 every 100 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.1)
# Send model to device
model = model.to(device)
# Train
num_epochs = 350
resnet_layers = 50
target_acc = 0.92
hardware = get_gpu_name(verbose=1) #'K80'
model, results_df = train_model(model, resnet_layers, hardware, dataloaders,
                                criterion, optimizer, exp_lr_scheduler, num_epochs,
                                save_epochs=save_epochs, save_dir=save_dir,
                                status_epochs=np.ceil(num_epochs/10),train_acc=target_acc)


# save the data for others to use
results_file = 'resnet50_{}.csv'.format(hardware)
df_path = os.path.join(save_dir,results_file)
results_df.to_csv(df_path,columns=results_df.columns)

# %% [markdown]
# _Note: this is the output from the actual training_
# ```
# GPU: K80
#
# Epoch 0/349
# ----------
# train Loss: 4.3678 Acc: 0.1331
# val Loss: 2.1291 Acc: 0.1891
# ----------------------------------|34
# Epoch 35/349
# ----------
# train Loss: 0.2296 Acc: 0.9184
# val Loss: 1.7887 Acc: 0.6465
#
# Epoch 36/349
# ----------
# train Loss: 0.2069 Acc: 0.9269
# val Loss: 1.9267 Acc: 0.6388
# Training complete in 111.0m 4.5717737674713135s
# Best val Acc: 0.6601
# ```
